# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# The above code imports necessary libraries: numpy, matplotlib, and pandas.
# It also sets up random data and demonstrates various matplotlib plotting techniques:
# - Creating histograms, scatter plots, bar plots, and line plots using matplotlib.
# - Customizing plot appearance with font dictionaries and axis labels.
# - Using seaborn to load the iris dataset and create KDE plots with different styles and overlays.
# - Adding scatter plots and customizing plot titles and labels for better visualization.

# %%
###This section generates random data and demonstrates how to create a histogram using matplotlib. The random seed ensures reproducibility, and the histogram visualizes the distribution of the generated values.

np.random.seed(613)  # For reproducibility
x = np.arange(50)
y = np.random.randint(0, 100, size=50)  


fig, ax = plt.subplots(figsize=(5, 3))
#ax.scatter(x,y)
#ax.bar(x,y)
#ax.barh(x,y)
#ax.plot(y)
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
//# Create a line plot of the random values in y to visualize their distribution.

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y)

ax.set_title('total growth over time', fontdict=font1, loc='left', pad=20)
ax.set_ylabel('total growth', fontdict=font2)
ax.set_xlabel('years since start', fontdict=font2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       1 # Create a line plot of the random values in y to visualize their distribution.
#       3 fig, ax = plt.subplots(figsize=(5, 3))
# ----> 4 ax.plot(x, y)
#       6 ax.set_title('total growth over time', fontdict=font1, loc='left', pad=20)
#       7 ax.set_ylabel('total growth', fontdict=font2)
#
# NameError: name 'x' is not defined

# %%
// Create a line plot of the random values in y to visualize their distribution.

fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,
           y,
           marker='*',
           color='indigo')

# %%
//practicing the Hideous plots 
import seaborn as sns

df = sns.load_dataset('iris')
sns.set_style("darkgrid")
sns.kdeplot(x=df.sepal_width, y=df.sepal_length)
plt.show()
sns.set_style("white")
sns.kdeplot(
    x=df.sepal_width, 
    y=df.sepal_length, 
    cmap="rainbow", 
    fill=True, 
    alpha=0.8, 
    bw_adjust=0.2, 
    thresh=0.01, 
    levels=20, 
    linewidths=3, 
    linestyles="dashed"
)
plt.scatter(df.sepal_width, df.sepal_length, c=np.random.rand(len(df)), s=200, marker='X', edgecolor='black', alpha=0.7)
plt.title("X PLOT!", fontsize=24, color='magenta', fontweight='bold')
plt.xlabel("Sepal Width", fontsize=16, color='red')
plt.ylabel("Sepal Length", fontsize=16, color='blue')
plt.show()
sns.set_style("white")
sns.kdeplot(x=df.sepal_width, y=df.sepal_length,
            cmap="Blues", fill=True, bw_adjust=0.5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 6
#       4 sns.set_style("darkgrid")
#       5 sns.kdeplot(x=df.sepal_width, y=df.sepal_length)
# ----> 6 plt.show()
#       7 sns.set_style("white")
#       8 sns.kdeplot(
#       9     x=df.sepal_width,
#      10     y=df.sepal_length,
#    (...)
#      18     linestyles="dashed"
#      19 )
#
# NameError: name 'plt' is not defined
