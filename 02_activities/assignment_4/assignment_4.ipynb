# %% [markdown]
# ## Data Visualizations Assignment-4

# %% [markdown]
# Introduction:
#
# For this assignment, I chose a dataset from the City of Toronto’s Open Data Portal. The dataset, titled "Community Housing Data," contains information about various community housing buildings in Toronto. It includes details such as building ID, development name, neighborhood number, postal code, total residential units, market units, rent-geared-to-income units, year built, and building description. This dataset is suitable for creating meaningful visualizations that can provide insights into the distribution and development of community housing in Toronto.

# %% [markdown]
# #### Visualization 1: Distribution of Total Residential Units by Neighborhood (Python)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the dataset
file_path = '/Users/mishavitvinov/Downloads/Community Housing Data - 4326.csv'
housing_data = pd.read_csv(file_path)

# Grouping data by neighborhood number and summing total residential units
neighborhood_data = housing_data.groupby('NGHBRHD_NUM')['TTL_RES_UNIT'].sum().reset_index()

# Plotting the distribution of total residential units by neighborhood
plt.figure(figsize=(12, 8))
sns.barplot(data=neighborhood_data, x='NGHBRHD_NUM', y='TTL_RES_UNIT', hue='NGHBRHD_NUM', palette='viridis', dodge=False, legend=False)
plt.title('Distribution of Total Residential Units by Neighborhood')
plt.xlabel('Neighborhood Number')
plt.ylabel('Total Residential Units')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('/Users/mishavitvinov/Downloads/Distribution_of_Residential_Units_by_Neighborhood.png')
plt.show()

# %% [markdown]
# #### Explanations for Visualization 1

# %% [markdown]
# Software Used: Python (Matplotlib/Seaborn)
#
#  - I used Python, leveraging the Matplotlib and Seaborn libraries, to create this visualization. These tools are powerful for data visualization and allow for a high degree of customization and reproducibility.
#
# Intended Audience: Urban planners, housing authorities, policymakers.
#  - The primary audience for this visualization includes urban planners, housing authorities, and policymakers who need to understand the distribution of residential units across different neighborhoods in Toronto to make informed decisions about housing policies and resource allocation.
#
# Information or Message: This visualization shows the distribution of residential units across different neighborhoods, helping identify areas with higher or lower concentrations of housing.
#  - The goal of this visualization is to convey the distribution of total residential units by neighborhood, highlighting areas with high or low concentrations of residential housing. This can help in identifying regions that may require more attention in terms of development or resource allocation.
#
# Design Principles:
#
#  - Substantive: The focus was on accurately representing the number of residential units in each neighborhood. The data was aggregated by neighborhood number and plotted to ensure clarity and accuracy.
#  - Perceptual: Clear bar heights and distinct colors were used to make comparisons easy. The color palette 'viridis' was chosen for its readability and accessibility.
#  - Aesthetic: A clean and simple design was implemented to ensure that the visualization is easily interpretable. The axes were labeled, and a title was added to provide context.
#
# Reproducibility: The Python code provided ensures that the visualization can be reproduced by anyone with access to the dataset and the code.
#
#  - The reproducibility of this visualization is ensured through the use of Python code. By providing the code, others can easily replicate the visualization with the same dataset, ensuring consistency and transparency.
#
# Accessibility: Chose colors that are colorblind-friendly, labeled axes, and added a title for context.
#
#  - Accessibility was considered by selecting a colorblind-friendly palette and ensuring that all elements of the plot are clearly labeled. The use of readable fonts and sizes also enhances accessibility.
#
# Impacted Communities: Residents, local government officials, and community organizations.
#  - The visualization impacts residents, local government officials, and community organizations by providing insights into the distribution of housing. This can inform decisions on where to focus development efforts or allocate resources.
#
# Feature Selection: Chose to focus on neighborhood number and total residential units to provide a clear and impactful visual representation.
#  - The features selected for this visualization were the neighborhood number and the total number of residential units. These features were chosen to provide a clear and direct representation of housing distribution across neighborhoods.
#
# Underwater Labour: Data cleaning, aggregation by neighborhood, and plotting.
#  - Significant effort went into data cleaning, aggregating the data by neighborhood, and creating the plot. This involved handling missing values, ensuring data accuracy, and fine-tuning the visualization for clarity and impact.

# %% [markdown]
# #### Visualization 2: Relationship between Year Built and Total Residential Units (Google Sheets)

# %% [markdown]
# ![Relationship between Year Built and Total Residential Units](Visualization_2.png)

# %% [markdown]
# Written Explanations for Visualization 2:
#
# Software Used: Google Sheets
#
#  - I used Google Sheets to create this visualization. Google Sheets is a free and widely accessible tool that allows for quick and easy creation of basic data visualizations.
#
# Intended Audience: Historians, real estate developers, urban studies researchers.
#
#  - The primary audience for this visualization includes historians, real estate developers, and urban studies researchers who are interested in understanding housing development trends over time.
#
# Information or Message: This visualization aims to show how the number of residential units has changed over time, providing insights into housing development trends.
#  - The goal of this visualization is to illustrate the relationship between the year a building was constructed and the total number of residential units it contains. This can reveal trends in housing development over time.
#
# Design Principles:
#
#  - Substantive: The visualization accurately represents the data, showing the relationship between year built and total residential units.
#  - Perceptual: A scatter plot with trend lines was used to make patterns and correlations easily identifiable.
#  - Aesthetic: Colors were used to differentiate data points clearly, and clear labels were added to enhance readability.
#
# Reproducibility: Instructions to import the dataset and create the visualization in Google Sheets ensure reproducibility.
#
#  - The reproducibility of this visualization is ensured through detailed instructions on how to recreate it using Google Sheets. By following these steps, others can produce the same visualization.
#
# Accessibility: Use of accessible colors, labeled axes, and trend lines.
#
#  - Accessibility considerations included the use of colors that are distinguishable by colorblind individuals, clear labeling of axes, and the inclusion of trend lines to aid in interpretation.
#
# Impacted Communities: Researchers, policymakers, developers, and the general public.
#
#  - The visualization impacts researchers, policymakers, developers, and the general public by providing valuable insights into historical trends in housing development.
#
# Feature Selection: Focused on year built and total residential units to highlight trends and patterns over time.
#
#  - The features selected for this visualization were the year built and the total residential units. These features were chosen to highlight trends and patterns in housing development over time.
#
# Underwater Labour: Data preparation, importing into Google Sheets, and customizing the visualization.
#
#  - Effort was required to prepare the data, import it into Google Sheets, and customize the visualization to ensure clarity and effectiveness.
