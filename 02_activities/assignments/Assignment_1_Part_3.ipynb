# %%
# 1. Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
# 2. Setting up random seed and sample data
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100, 50)
y2 = np.random.randint(0, 100, 50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2_bar = np.array([110, 180, 240, 99, 220])

# %%
# 3. Basic plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y1)
ax.plot(x, y2)

# %%
# 4. Adding labels and legend
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y1, label="Person 1")
ax.plot(x, y2, label="Person 2")
ax.legend(loc="lower right")

# %%
# 5. Customizing legend with font size and shadow
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y1, label="Person 1")
ax.plot(x, y2, label="Person 2")
ax.legend(loc="lower right", frameon=True, fontsize=12, ncol=2, shadow=True)

# %%
# 6. Adjusting legend position using bbox_to_anchor
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y1, label="Person 1")
ax.plot(x, y2, label="Person 2")
ax.legend(loc="upper left", bbox_to_anchor=(1, 1))

# %%
# 7. Text annotation on the plot
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, y1, label="Person 1")
ax.scatter(x, y2, label="Person 2")
ax.legend(loc="lower right")
ax.text(10, 95, "This value is important!")
# Out:
# Text(10, 95, 'This value is important!')

# %%
# 8. Text annotation with custom styling
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, y1, label="Person 1")
ax.scatter(x, y2, label="Person 2")
ax.legend(loc="lower right")
ax.text(10, 95, "This value is important!", ha="center", color="red", size=20)
# Out:
# Text(10, 95, 'This value is important!')

# %%
# 9. Using different coordinate systems for annotations
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])
ax.text(1, 5, ". Data: (1, 5)", transform=ax.transData)
ax.text(0.5, 0.1, ". Axes: (0.5, 0.1)", transform=ax.transAxes)
ax.text(0.2, 0.2, ". Figure: (0.2, 0.2)", transform=fig.transFigure)
# Out:
# Text(0.2, 0.2, '. Figure: (0.2, 0.2)')

# %%
# 10. Adding arrows with annotation
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, y1, label="Person 1")
ax.scatter(x, y2, label="Person 2")
ax.legend(loc="lower right")
ax.annotate("This is important!", xy=(10, 95), xytext=(20, 94), 
            arrowprops=dict(facecolor="black", shrink=0.05))
# Out:
# Text(20, 94, 'This is important!')

# %%
# 11. Removing ticks and labels
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, y1, label="Person 1")
ax.scatter(x, y2, label="Person 2")
ax.legend(loc="lower right")
ax.yaxis.set_major_locator(plt.NullLocator())  # Remove ticks
ax.xaxis.set_major_formatter(plt.NullFormatter())  # Remove only labels

# %%
# 12. Using MaxNLocator for x-axis
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, y1, label="Person 1")
ax.scatter(x, y2, label="Person 2")
ax.legend(loc="lower right")
ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
# 13. Customizing tick marks with MultipleLocator
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, y1, label="Person 1")
ax.scatter(x, y2, label="Person 2")
ax.legend(loc="lower right")
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %%
# 14. Rotating x-ticks and adjusting font style
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x, y1, label="Person 1")
ax.scatter(x, y2, label="Person 2")
ax.legend(loc="lower right")
plt.xticks(rotation=45, ha="right", fontsize=12, font="serif")
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
# 15. Adding an x-axis label with custom font
font1 = {'family': 'serif', 'color': 'indigo'}
plt.xlabel("Shiny New X Axis!", fontsize=18, fontdict=font1)
# Out:
# Text(0.5, 0, 'Shiny New X Axis!')

# %%
# 16. Using a custom Matplotlib style
plt.style.use("fivethirtyeight")
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x, y1)

# %%
# 17. Creating subplots for scatter and bar charts
fig, (ax1, ax2) = plt.subplots(ncols=2, nrows=1, figsize=(7, 3))
ax1.scatter(x, y1)
ax2.bar(x2, y2_bar)
# Out:
# <BarContainer object of 5 artists>

# %%
# 18. Adding titles and labels to subplots
font2 = {'family': 'serif', 'size': 14}
ax1.set_title("Important Scatterplot", fontdict=font2)
ax1.set_ylabel("Measure", fontdict=font1)
ax1.set_xlabel("Time", fontdict=font1)
# Out:
# Text(0.5, 4.444444444444448, 'Time')

# %%
# 19. Creating a mosaic of subplots
fig, someaxes = plt.subplot_mosaic([["ax1", "ax3"], ["ax2", "ax3"]], figsize=(7, 4))
someaxes["ax1"].scatter(x, y1)
someaxes["ax2"].bar(x2, y2_bar)
someaxes["ax3"].plot(x, y1)

# %%
# 20. Adding labels to mosaic subplots
someaxes["ax1"].set_xlabel("A Big Label", fontsize=18)
someaxes["ax2"].set_xlabel("Another Label", fontsize=18)
someaxes["ax3"].set_xlabel("Label 2: 2 Fast 2 Furious", fontsize=18)
# Out:
# Text(0.5, 4.444444444444448, 'Label 2: 2 Fast 2 Furious')

# %%
# Adding labels to each subplot in the mosaic
fig, someaxes = plt.subplot_mosaic([["ax1", "ax3"], ["ax2", "ax3"]], figsize=(7, 4))

# Plotting different types of charts
someaxes["ax1"].scatter(x, y1)
someaxes["ax2"].bar(x2, y2_bar)
someaxes["ax3"].plot(x, y1)

# Adding unique x-axis labels to each subplot
someaxes["ax1"].set_xlabel("A Big Label", fontsize=18)
someaxes["ax2"].set_xlabel("Another Label", fontsize=18)
someaxes["ax3"].set_xlabel("Label 2: 2 Fast 2 Furious", fontsize=18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')
