# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0,100,50)
y2 = np.random.randint(0,100,50)

# %%
fig, ax = plt.subplots(figsize=(5,3)) 
ax.plot(x,y1)
ax.plot(x,y1)
fig.show()
# Out:
# /var/folders/nb/8xqrwtxj0g38cgj_rm5pgfvr0000gn/T/ipykernel_23541/2063669480.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# /var/folders/nb/8xqrwtxj0g38cgj_rm5pgfvr0000gn/T/ipykernel_23541/1247310572.py:4: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend (loc = 'lower right', 
           frameon = True, 
           fontsize = 12,
           ncol = 2,
           shadow = True)

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc="lower right")

ax.text(10,95,"This value is important!",
        ha = 'center',
        color = 'red',
        size = 20)
# Out:
# Text(10, 95, 'This value is important!')

# %%
fig, ax = plt.subplots()
ax.axis([0,10,0,10])

ax.text(1,5, ". Data: (1,5)", transform=ax.transData)
ax.text(0.5, 0.1, ". Axes: (0.5, 0.1)", transform=ax.transAxes)
ax.text(0.2, 0.2, ". Figure:(0.2, 0.2)", transform=fig.transFigure)
# Out:
# Text(0.2, 0.2, '. Figure:(0.2, 0.2)')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1,label="Person 1")
ax.scatter(x,y2,label="Person 2")
ax.legend(loc="lower right")

ax.annotate('This is important', xy = (10,95), xytext = (20,94),
        arrowprops=dict(arrowstyle = "wedge",
                        color = "hotpink"))
# Out:
# Text(20, 94, 'This is important')

# %%
fig, ax = plt.subplots(figsize = (5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

#ax.yaxis.set_major_locator(plt.NullLocator())
#ax.xaxis.set_major_formatter(plt.NullFormatter())

#ax.xaxis.set_major_locator(plt.MaxNLocator(3))

#ax.xaxis.set_major_locator(p.t.MultipleLocator(5))

#plt.xticks(rotation=45, ha = "right, fontsize = 12, font = 'serif")

# %%
font1 = {'family':'serif', 'color':'indigo'}
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xlabel('Shiny New X Axis!', fontsize = 18, fontdict = font1)
# Out:
# Text(0.5, 0, 'Shiny New X Axis!')

# %%
plt.style.use('fivethirtyeight')

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# /var/folders/nb/8xqrwtxj0g38cgj_rm5pgfvr0000gn/T/ipykernel_23541/1039124237.py:10: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0,75,50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2 = np.array([110,180,240,99,220])

# %%
#fig, ax = plt.subplots(figsize=(5,3))
fig, (ax1, ax2) = plt.subplots(ncols=2,
                              nrows=1,
                              figsize = (7,3))

ax1.scatter(x1,y1)
ax2.bar(x2, y2)
# Out:
# <BarContainer object of 5 artists>

# %%
#Review
font1 = {'family':'san-serif', 'color':'grey'}
fig, (ax1, ax2) = plt.subplots(ncols=2,
                              nrows=1,
                              figsize = (7,3))

ax1.scatter(x1,y1,
            marker = '*')
ax2.bar(x2, y2)

ax1.set_title('Scatterplot', fontdict = font1)
ax1.set_ylabel('Measure', fontdict = font1)
ax1.set_xlabel('Time', fontdict = font1)
# Out:
# Text(0.5, 0, 'Time')
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.
# findfont: Font family 'san-serif' not found.

# %%
fig, someaxes = plt.subplot_mosaic([['ax1','ax3'],
                                    ['ax2','ax3']],
                                    figsize = (7,4))

someaxes['ax1'].scatter(x1,y1)
someaxes['ax2'].bar(x2,y2)
someaxes['ax3'].plot(x1,y1)

# %%
fig, someaxes = plt.subplot_mosaic([['ax1','ax3'],
                                    ['ax2','ax3']],
                                    figsize = (7,4),
                                    layout = "constrained")

someaxes['ax1'].scatter(x1,y1)
someaxes['ax2'].bar(x2,y2)
someaxes['ax3'].plot(x1,y1)

someaxes['ax1'].set_xlabel('A Big Label', fontsize = 18)
someaxes['ax2'].set_xlabel('Another One', fontsize = 18)
someaxes['ax3'].set_xlabel('Label 2: 2 Fast 2 Furious', fontsize = 18)
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
x = np. array(['Luffy', 'zoro', 'Nami', 'Usopp', 'Sanji'])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100j, 90, 120, 50])

fig, ax = plt.subplots(figsize = (7,3))
ax.bar(x,y1, color = 'indigo')
ax.plot(x,y2, color = 'red')
# Out:
# /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x, y2, color = 'red')

ax.errorbar(x, y2, 
            yerr = y2_sd,
            fmt = "none")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 6
#       3 fig, ax = plt.subplots(figsize=(7,3))
#       4 ax.plot(x, y2, color = 'red')
# ----> 6 ax.errorbar(x, y2,
#       7             yerr = y2_sd,
#       8             fmt = "none")
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/axes/_axes.py:3649, in Axes.errorbar(self, x, y, yerr, xerr, fmt, ecolor, elinewidth, capsize, barsabove, lolims, uplims, xlolims, xuplims, errorevery, capthick, **kwargs)
#    3644 # This is like
#    3645 #     elow, ehigh = np.broadcast_to(...)
#    3646 #     return dep - elow * ~lolims, dep + ehigh * ~uplims
#    3647 # except that broadcast_to would strip units.
#    3648 low, high = dep + np.row_stack([-(1 - lolims), 1 - uplims]) * err
# -> 3649 barcols.append(lines_func(
#    3650     *apply_mask([indep, low, high], everymask), **eb_lines_style))
#    3651 if self.name == "polar" and dep_axis == "x":
#    3652     for b in barcols:
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1170, in Axes.vlines(self, x, ymin, ymax, colors, linestyles, label, **kwargs)
#    1168 masked_verts = np.ma.empty((len(x), 2, 2))
#    1169 masked_verts[:, 0, 0] = x
# -> 1170 masked_verts[:, 0, 1] = ymin
#    1171 masked_verts[:, 1, 0] = x
#    1172 masked_verts[:, 1, 1] = ymax
#
# File /opt/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/numpy/ma/core.py:3371, in MaskedArray.__setitem__(self, indx, value)
#    3368     mval = tuple([False] * len(_dtype.names))
#    3369 if _mask is nomask:
#    3370     # Set the data, then the mask
# -> 3371     _data[indx] = dval
#    3372     if mval is not nomask:
#    3373         _mask = self._mask = make_mask_none(self.shape, _dtype)
#
# TypeError: can't convert complex to float
