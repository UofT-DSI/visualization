# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset using a specified encoding
file_path = r'C:\workspaceRezaDSI\visualization\02_activities\assignments\ltep-survey-results-all.csv'
data = pd.read_csv(file_path, encoding='latin1')  # Use 'latin1' 

# Check the first few rows to confirm successful loading
print(data.head())
# Out:
#    RespondentID   StartDate     EndDate  \
# 0           NaN         NaN         NaN
# 1  2.814052e+09  09/17/2013  09/17/2013
# 2  2.814020e+09  09/17/2013  09/17/2013
# 3  2.814015e+09  09/17/2013  09/17/2013
# 4  2.813972e+09  09/17/2013  09/17/2013
#
#   Province-wide conservation programs are established by the Ontario government and delivered by local utilities to help people save energy and reduce their electricity bills. Conservation can mean energy efficiency (e.g. more efficient appliances or better insulated buildings) or changing behaviour (reducing how much power you consume). ?Demand response? is another kind of conservation to help manage the amount of electricity used when it?s at its most expensive, as a way of limiting the need for new sources. Where do you think the government should be making the most effort to manage electricity demand?     Drag and drop the following statements to rank them in order of importance, 1 being the most important.  \
# ...

# %%
column_name = 'A significant amount of Ontario?s conservation and demand management is delivered by programs run by local electricity utilities. What is your impression of how well your local community is doing to reduce electricity demand? (Choose one)'

# %%
# Remove encoding artifacts
data.columns = data.columns.str.replace('?', '', regex=False)
data.columns = data.columns.str.strip()

# %%
print(data.columns)
# Out:
# Index(['RespondentID', 'StartDate', 'EndDate',
#        'Province-wide conservation programs are established by the Ontario government and delivered by local utilities to help people save energy and reduce their electricity bills. Conservation can mean energy efficiency (e.g. more efficient appliances or better insulated buildings) or changing behaviour (reducing how much power you consume). Demand response is another kind of conservation to help manage the amount of electricity used when its at its most expensive, as a way of limiting the need for new sources. Where do you think the government should be making the most effort to manage electricity demand     Drag and drop the following statements to rank them in order of importance, 1 being the most important.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9',
# ...

# %%
# Ensure column exists and extract response counts
if column_name in data.columns:
    response_counts = data[column_name].value_counts()

    # Plotting the bar chart
    plt.figure(figsize=(10, 6))
    sns.barplot(x=response_counts.values, y=response_counts.index, palette='viridis')
    plt.title('Impressions on Local Conservation Programs', fontsize=16)
    plt.xlabel('Number of Responses', fontsize=12)
    plt.ylabel('Response Category', fontsize=12)
    plt.tight_layout()
    plt.savefig('local_conservation_bar_chart.png', dpi=300)
    plt.show()
else:
    print(f"Column '{column_name}' not found in the dataset!")
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_21228\3333973779.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=response_counts.values, y=response_counts.index, palette='viridis')
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_21228\3333973779.py:11: UserWarning: Glyph 130 (\x82) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_21228\3333973779.py:11: UserWarning: Glyph 138 (\x8a) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_21228\3333973779.py:11: UserWarning: Glyph 133 (\x85) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %%
data.columns = data.columns.str.strip()  # Removes extra spaces
data.columns = data.columns.str.replace('?', '', regex=False)  # Replaces unusual characters

# %%
# Correct column name for energy source proportions
column_name = 'Last year, Ontarios mix of energy sources was 53% nuclear, 21% hydro, 13% natural gas, 5% wind and solar, 3% coal and 5% conservation.'

# Manually defining proportions from the column description
energy_sources = ['Nuclear', 'Hydro', 'Natural Gas', 'Wind and Solar', 'Coal', 'Conservation']
proportions = [53, 21, 13, 5, 3, 5]  # Add these percentages based on the column description

# Plotting pie chart
plt.figure(figsize=(8, 8))
plt.pie(proportions, labels=energy_sources, autopct='%1.1f%%', startangle=140, colors=['#66b3ff', '#99ff99', '#ffcc99', '#ff9999', '#c2c2f0', '#ffb3e6'])
plt.title('Ontario Energy Source Proportions', fontsize=16)
plt.savefig('ontario_energy_pie_chart.png', dpi=300)
plt.show()

# %%
# Plotting heatmap with adjusted format for floats
plt.figure(figsize=(8, 6))
sns.heatmap(df_regions_pivot, annot=True, fmt=".1f", cmap='coolwarm', cbar=True)  # Changed fmt to ".1f"
plt.title('Regional Energy Needs and Agreement Levels', fontsize=16)
plt.xlabel('Agreement (%)', fontsize=12)
plt.ylabel('Region', fontsize=12)
plt.savefig('regional_energy_needs_heatmap.png', dpi=300)
plt.show()
