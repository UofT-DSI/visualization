# %% [markdown]
# ## Bicycle usage in Toronto by location between 2024-2025 going eastbound or northbound

# %% [markdown]
# This dataset was downloaded from: https://open.toronto.ca/dataset/permanent-bicycle-counters/
#
# It contains counts of bicycles from permanent detectors installed on Toronto streets and multi-use paths.
#
# The city uses the data to monitor trends in people cycling and the seasonal use of bicycle lanes.
#
# Additional new count stations are being added to the system and the data has not been brought online (validation pending).
#
# The files downloaded were:
# 1. cycling_permanent_counts_15min_2024_2025.csv
# 2. cycling_permanent_counts_locations.csv
# 3. cycling_permanent_counts_locations_geojson.geojson
#
# Considerations:
# Only bicycles and other micromobility devices (e-bikes, scooters, e-scooters) passing the detection zone in the bicycle lanes are counted- excluding riders on sidewalks, in motor-vehicle lanes or painted buffer zones.

# %% [markdown]
# ### Downloading packages if using conda/Anaconda
# In command line use:
#
# conda install -c conda-forge name_of_package

# %%
#Load libraries

import pandas as pd
import json
import folium #map rendering library from geospatial data
from branca.colormap import LinearColormap #for our tiles in the map, it provides colormap classes for creating and customizing color schemes

# %%
#Load data

#create function that takes file path and reads a csv file
#this is good for reproducibility, since the file path
#will be different for every person

def import_csv_file(file_path):
    df = pd.read_csv(file_path)
    return df

#create two files with the bicycle location information
df_2024_2025 = import_csv_file("C:\\Users\\miyoh\\UofT_DSI_Miyo\\Visualization\\visualization\\02_activities\\assignments\\cycling_permanent_counts_15min_2024_2025.csv")
df_all_detectors = import_csv_file("C:\\Users\\miyoh\\UofT_DSI_Miyo\\Visualization\\visualization\\02_activities\\assignments\\cycling_permanent_counts_locations.csv")

# %%
#Import geojson file using function for reproducibility, same as above

def import_geojson(filename):
    with open(filename, 'r') as f:
        return json.load(f)

geojson_data = import_geojson("C:\\Users\\miyoh\\UofT_DSI_Miyo\\Visualization\\visualization\\02_activities\\assignments\\cycling_permanent_counts_locations_geojson.geojson")

# %%
#select detectors that were working up until 2025 and were checking eastbound and northbound bikes

df_2025_detectors_2 = df_all_detectors[df_all_detectors["last_active"].str.contains("2025")] #up until 2025 using str that contains the date 2025 from the "last_active" column
df_2025_detectors_east = df_2025_detectors_2[df_2025_detectors_2["direction"].str.contains("Eastbound")] #filter direction for eastbound
df_2025_detectors_north = df_2025_detectors_2[df_2025_detectors_2["direction"].str.contains("Northbound")] #filter direction for northbound
df_2025_detectors_all = pd.merge(df_2025_detectors_east,df_2025_detectors_north, how= 'outer') #combine the two sub datasets

# %%
df_2025_detectors_all #visualize how the merged dataset looks
# Out:
#     _id  location_dir_id                                      location_name  \
# 0     3                3         Bloor St W at Oakmount Rd, Display Counter
# 1     8                8           Bloor St W, between Palmerston & Markham
# 2    12               12                 Bloor St W, East of Old Mill Trail
# 3    14               14      Multi-use path south-east of Keele & Sheppard
# 4    16               16  Multi-use path south of Sheppard Ave at Sentin...
# 5    18               18                 Sherbourne St, North of Gerrard St
# 6    22               22             Sherbourne St, North of Wellesley St E
# 7    26               26                        Yonge St, North of Bloor St
# 8    28               28                    Yonge St, North of Davenport Rd
# 9    30               30                  Yonge St, North of Macpherson Ave
# 10   32               32                    Yonge St, North of St Clair Ave
#
#      direction linear_name_full      side_street  longitude   latitude  \
# 0    Eastbound       Bloor St W      Oakmount Rd -79.462570  43.654146
# 1    Eastbound       Bloor St W  Palmerston Blvd -79.413093  43.664726
# 2    Eastbound       Bloor St W   Old Mill Trail -79.494243  43.649091
# 3   Northbound         Keele St   Sheppard Ave W -79.486137  43.744488
# 4    Eastbound   Sheppard Ave W      Sentinel Rd -79.492129  43.743467
# 5   Northbound    Sherbourne St       Gerrard St -79.372567  43.662038
# 6   Northbound    Sherbourne St   Wellesley St E -79.375044  43.667971
# 7   Northbound         Yonge St         Bloor St -79.386893  43.670559
# 8   Northbound         Yonge St     Davenport Rd -79.388063  43.673443
# 9   Northbound         Yonge St   Macpherson Ave -79.390566  43.679541
# 10  Northbound         Yonge St     St Clair Ave -79.394426  43.688853
#
#     centreline_id  bin_size latest_calibration_study first_active last_active  \
# 0        30042273  00:15:00               2023-10-18   2023-06-16  2025-02-09
# 1         8353520  00:15:00               2024-10-02   2023-03-31  2025-03-02
# 2        30081325  00:15:00               2024-10-02   2024-07-31  2025-03-02
# 3        10133019  00:15:00               2023-10-18   2022-08-06  2025-03-02
# 4         6002161  00:15:00               2023-10-18   2023-03-28  2025-01-10
# 5         1143580  00:15:00               2023-10-18   2022-11-14  2025-03-02
# 6        10923449  00:15:00               2024-10-02   2022-11-15  2025-01-20
# 7        11034877  00:15:00               2024-10-02   2022-10-27  2025-03-02
# 8         8680067  00:15:00               2024-10-02   2024-01-15  2025-03-02
# 9         1140465  00:15:00               2024-10-03   2022-11-14  2025-03-02
# 10        7262532  00:15:00               2024-10-02   2022-11-14  2025-03-02
#
#    date_decommissioned               technology
# 0                  NaN  Induction - Eco-Counter
# 1                  NaN  Induction - Eco-Counter
# 2                  NaN  Induction - Eco-Counter
# 3                  NaN  Induction - Eco-Counter
# 4                  NaN  Induction - Eco-Counter
# 5                  NaN  Induction - Eco-Counter
# 6                  NaN  Induction - Eco-Counter
# 7                  NaN  Induction - Eco-Counter
# 8                  NaN  Induction - Eco-Counter
# 9                  NaN  Induction - Eco-Counter
# 10                 NaN  Induction - Eco-Counter

# %%
#See how the 2024 data looks like
df_2024_2025.head(5)
# Out:
#    _id  location_dir_id         datetime_bin  bin_volume
# 0    1                3  2024-01-01T00:00:00           0
# 1    2                3  2024-01-01T00:15:00           0
# 2    3                3  2024-01-01T00:30:00           0
# 3    4                3  2024-01-01T00:45:00           0
# 4    5                3  2024-01-01T01:00:00           1

# %%
#keep 2024-2025 data only by performing pandas inner join
df_merged = pd.merge(df_2025_detectors_all, df_2024_2025, on="location_dir_id", how = "inner")

# %%
#keep the neccessary columns
df_merged = df_merged[['location_dir_id', 'location_name','direction', 'longitude', 'latitude', 'centreline_id']]

# %%
#I need to sum my CSV data by location_dir_id to get the count of cyclists, I have to group by the columns so that the information is retained
cyclist_data_by_id = df_merged.groupby(['location_dir_id', 'location_name', 'longitude', 'latitude', 'direction']).size().reset_index(name="sum")

# %%
#see what the grouping by did

cyclist_data_by_id.head()
# Out:
#    location_dir_id                                      location_name  \
# 0                3         Bloor St W at Oakmount Rd, Display Counter
# 1                8           Bloor St W, between Palmerston & Markham
# 2               12                 Bloor St W, East of Old Mill Trail
# 3               14      Multi-use path south-east of Keele & Sheppard
# 4               16  Multi-use path south of Sheppard Ave at Sentin...
#
#    longitude   latitude   direction    sum
# 0 -79.462570  43.654146   Eastbound  34944
# 1 -79.413093  43.664726   Eastbound  28416
# 2 -79.494243  43.649091   Eastbound  14784
# 3 -79.486137  43.744488  Northbound  34752
# 4 -79.492129  43.743467   Eastbound  32544

# %%
#read geojson_data 
geojson_data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'id': 1,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3681194, 43.6738047]},
#    'properties': {'location_dir_id': 1,
#     'location_name': 'Bloor St E, West of Castle Frank Rd (retired)',
#     'direction': 'Eastbound',
#     'linear_name_full': 'Bloor St E',
#     'side_street': 'Castle Frank Rd',
#     'centreline_id': 8540609,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': None,
#     'first_active': '1994-06-26',
#     'last_active': '2019-06-13',
#     'date_decommissioned': '2019-06-13',
#     'technology': 'Induction - Other'}},
#   {'type': 'Feature',
#    'id': 2,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3681194, 43.6738047]},
#    'properties': {'location_dir_id': 2,
#     'location_name': 'Bloor St E, West of Castle Frank Rd (retired)',
#     'direction': 'Westbound',
#     'linear_name_full': 'Bloor St E',
#     'side_street': 'Castle Frank Rd',
#     'centreline_id': 8540609,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': None,
#     'first_active': '1994-06-26',
#     'last_active': '2019-06-13',
#     'date_decommissioned': '2019-06-13',
#     'technology': 'Induction - Other'}},
#   {'type': 'Feature',
#    'id': 3,
#    'geometry': {'type': 'Point', 'coordinates': [-79.4625696, 43.6541459]},
#    'properties': {'location_dir_id': 3,
#     'location_name': 'Bloor St W at Oakmount Rd, Display Counter',
#     'direction': 'Eastbound',
#     'linear_name_full': 'Bloor St W',
#     'side_street': 'Oakmount Rd',
#     'centreline_id': 30042273,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2023-10-18',
#     'first_active': '2023-06-16',
#     'last_active': '2025-03-17',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 22,
#    'geometry': {'type': 'Point', 'coordinates': [-79.375044, 43.6679708]},
#    'properties': {'location_dir_id': 22,
#     'location_name': 'Sherbourne St, North of Wellesley St E',
#     'direction': 'Northbound',
#     'linear_name_full': 'Sherbourne St',
#     'side_street': 'Wellesley St E',
#     'centreline_id': 10923449,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2022-11-15',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 23,
#    'geometry': {'type': 'Point', 'coordinates': [-79.375044, 43.6679708]},
#    'properties': {'location_dir_id': 23,
#     'location_name': 'Sherbourne St, North of Wellesley St E',
#     'direction': 'Southbound',
#     'linear_name_full': 'Sherbourne St',
#     'side_street': 'Wellesley St E',
#     'centreline_id': 10923449,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2022-11-15',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 24,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3748765, 43.6677188]},
#    'properties': {'location_dir_id': 24,
#     'location_name': 'Sherbourne St, North of Wellesley St E (retired)',
#     'direction': 'Northbound',
#     'linear_name_full': 'Sherbourne St',
#     'side_street': 'Wellesley St E',
#     'centreline_id': 10923449,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': None,
#     'first_active': '2014-04-30',
#     'last_active': '2019-06-02',
#     'date_decommissioned': '2019-06-03',
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 25,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3751043, 43.6679505]},
#    'properties': {'location_dir_id': 25,
#     'location_name': 'Sherbourne St, North of Wellesley St E (retired)',
#     'direction': 'Southbound',
#     'linear_name_full': 'Sherbourne St',
#     'side_street': 'Wellesley St E',
#     'centreline_id': 10923449,
#     'bin_size': '01:00:00',
#     'latest_calibration_study': None,
#     'first_active': '2014-04-11',
#     'last_active': '2019-06-02',
#     'date_decommissioned': '2019-06-03',
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 26,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3868925, 43.6705587]},
#    'properties': {'location_dir_id': 26,
#     'location_name': 'Yonge St, North of Bloor St',
#     'direction': 'Northbound',
#     'linear_name_full': 'Yonge St',
#     'side_street': 'Bloor St',
#     'centreline_id': 11034877,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2022-10-27',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 27,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3868925, 43.6705587]},
#    'properties': {'location_dir_id': 27,
#     'location_name': 'Yonge St, North of Bloor St',
#     'direction': 'Southbound',
#     'linear_name_full': 'Yonge St',
#     'side_street': 'Bloor St',
#     'centreline_id': 11034877,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2022-10-27',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 28,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3880628, 43.6734429]},
#    'properties': {'location_dir_id': 28,
#     'location_name': 'Yonge St, North of Davenport Rd',
#     'direction': 'Northbound',
#     'linear_name_full': 'Yonge St',
#     'side_street': 'Davenport Rd',
#     'centreline_id': 8680067,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2024-01-15',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 29,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3880628, 43.6734429]},
#    'properties': {'location_dir_id': 29,
#     'location_name': 'Yonge St, North of Davenport Rd',
#     'direction': 'Southbound',
#     'linear_name_full': 'Yonge St',
#     'side_street': 'Davenport Rd',
#     'centreline_id': 8680067,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2022-11-14',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 30,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3905663, 43.6795414]},
#    'properties': {'location_dir_id': 30,
#     'location_name': 'Yonge St, North of Macpherson Ave',
#     'direction': 'Northbound',
#     'linear_name_full': 'Yonge St',
#     'side_street': 'Macpherson Ave',
#     'centreline_id': 1140465,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-03',
#     'first_active': '2022-11-14',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 31,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3905663, 43.6795414]},
#    'properties': {'location_dir_id': 31,
#     'location_name': 'Yonge St, North of Macpherson Ave',
#     'direction': 'Southbound',
#     'linear_name_full': 'Yonge St',
#     'side_street': 'Macpherson Ave',
#     'centreline_id': 1140465,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-03',
#     'first_active': '2024-06-23',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 32,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3944265, 43.6888532]},
#    'properties': {'location_dir_id': 32,
#     'location_name': 'Yonge St, North of St Clair Ave',
#     'direction': 'Northbound',
#     'linear_name_full': 'Yonge St',
#     'side_street': 'St Clair Ave',
#     'centreline_id': 7262532,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2022-11-14',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 33,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3944265, 43.6888532]},
#    'properties': {'location_dir_id': 33,
#     'location_name': 'Yonge St, North of St Clair Ave',
#     'direction': 'Southbound',
#     'linear_name_full': 'Yonge St',
#     'side_street': 'St Clair Ave',
#     'centreline_id': 7262532,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2022-11-14',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 34,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3965356, 43.697978]},
#    'properties': {'location_dir_id': 34,
#     'location_name': 'Yonge St, South of Davisville Ave',
#     'direction': 'Northbound',
#     'linear_name_full': 'Yonge St',
#     'side_street': 'Davisville Ave',
#     'centreline_id': 7273833,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2022-11-14',
#     'last_active': '2025-03-29',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 35,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3965356, 43.697978]},
#    'properties': {'location_dir_id': 35,
#     'location_name': 'Yonge St, South of Davisville Ave',
#     'direction': 'Southbound',
#     'linear_name_full': 'Yonge St',
#     'side_street': 'Davisville Ave',
#     'centreline_id': 7273833,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2022-11-23',
#     'last_active': '2025-03-29',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 36,
#    'geometry': {'type': 'Point', 'coordinates': [-79.49192, 43.766102]},
#    'properties': {'location_dir_id': 36,
#     'location_name': 'YorkU - Keele St, North of Four Winds Dr',
#     'direction': 'Northbound',
#     'linear_name_full': 'Keele St',
#     'side_street': 'Four Winds Dr',
#     'centreline_id': 439433,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2023-10-18',
#     'first_active': '2022-06-07',
#     'last_active': '2025-03-19',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 37,
#    'geometry': {'type': 'Point', 'coordinates': [-79.49192, 43.766102]},
#    'properties': {'location_dir_id': 37,
#     'location_name': 'YorkU - Keele St, North of Four Winds Dr',
#     'direction': 'Southbound',
#     'linear_name_full': 'Keele St',
#     'side_street': 'Four Winds Dr',
#     'centreline_id': 439433,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2023-10-18',
#     'first_active': '2022-06-07',
#     'last_active': '2025-03-19',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 38,
#    'geometry': {'type': 'Point', 'coordinates': [-79.5145151, 43.773275]},
#    'properties': {'location_dir_id': 38,
#     'location_name': 'YorkU - Murray Ross Pkwy, North of Shoreham Dr',
#     'direction': 'Northbound',
#     'linear_name_full': 'Murray Ross Pkwy',
#     'side_street': 'Shoreham Dr',
#     'centreline_id': 30091481,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2023-10-18',
#     'first_active': '2022-05-31',
#     'last_active': '2024-12-05',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 39,
#    'geometry': {'type': 'Point', 'coordinates': [-79.5145151, 43.773275]},
#    'properties': {'location_dir_id': 39,
#     'location_name': 'YorkU - Murray Ross Pkwy, North of Shoreham Dr',
#     'direction': 'Southbound',
#     'linear_name_full': 'Murray Ross Pkwy',
#     'side_street': 'Shoreham Dr',
#     'centreline_id': 30091481,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2023-10-18',
#     'first_active': '2022-05-31',
#     'last_active': '2024-12-05',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 4,
#    'geometry': {'type': 'Point', 'coordinates': [-79.4625696, 43.6541459]},
#    'properties': {'location_dir_id': 4,
#     'location_name': 'Bloor St W at Oakmount Rd, Display Counter',
#     'direction': 'Westbound',
#     'linear_name_full': 'Bloor St W',
#     'side_street': 'Oakmount Rd',
#     'centreline_id': 30042273,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2023-10-18',
#     'first_active': '2023-06-16',
#     'last_active': '2025-03-17',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 5,
#    'geometry': {'type': 'Point', 'coordinates': [-79.4022396, 43.6670654]},
#    'properties': {'location_dir_id': 5,
#     'location_name': 'Bloor St W between Huron St & Spadina Ave',
#     'direction': 'Eastbound',
#     'linear_name_full': 'Bloor St W',
#     'side_street': 'Huron St',
#     'centreline_id': 1142672,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': None,
#     'first_active': '2022-10-27',
#     'last_active': '2023-07-22',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 6,
#    'geometry': {'type': 'Point', 'coordinates': [-79.4022396, 43.6670654]},
#    'properties': {'location_dir_id': 6,
#     'location_name': 'Bloor St W between Huron St & Spadina Ave',
#     'direction': 'Westbound',
#     'linear_name_full': 'Bloor St W',
#     'side_street': 'Huron St',
#     'centreline_id': 1142672,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': None,
#     'first_active': '2022-10-27',
#     'last_active': '2023-07-22',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 7,
#    'geometry': {'type': 'Point', 'coordinates': [-79.4022206, 43.6669895]},
#    'properties': {'location_dir_id': 7,
#     'location_name': 'Bloor St W between Huron St & Spadina Ave (retired)',
#     'direction': 'Westbound',
#     'linear_name_full': 'Bloor St W',
#     'side_street': 'Huron St',
#     'centreline_id': 1142672,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': None,
#     'first_active': '2018-02-09',
#     'last_active': '2021-02-08',
#     'date_decommissioned': '2022-06-02',
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 8,
#    'geometry': {'type': 'Point', 'coordinates': [-79.413093, 43.6647258]},
#    'properties': {'location_dir_id': 8,
#     'location_name': 'Bloor St W, between Palmerston & Markham',
#     'direction': 'Eastbound',
#     'linear_name_full': 'Bloor St W',
#     'side_street': 'Palmerston Blvd',
#     'centreline_id': 8353520,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2023-03-31',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 9,
#    'geometry': {'type': 'Point', 'coordinates': [-79.413093, 43.6647258]},
#    'properties': {'location_dir_id': 9,
#     'location_name': 'Bloor St W, between Palmerston & Markham',
#     'direction': 'Westbound',
#     'linear_name_full': 'Bloor St W',
#     'side_street': 'Palmerston Blvd',
#     'centreline_id': 8353520,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2023-03-31',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 10,
#    'geometry': {'type': 'Point', 'coordinates': [-79.413079, 43.6647238]},
#    'properties': {'location_dir_id': 10,
#     'location_name': 'Bloor St W, between Palmerston & Markham (retired)',
#     'direction': 'Eastbound',
#     'linear_name_full': 'Bloor St W',
#     'side_street': 'Palmerston Blvd',
#     'centreline_id': 8353520,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': None,
#     'first_active': '2018-02-09',
#     'last_active': '2020-02-11',
#     'date_decommissioned': '2020-02-12',
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 11,
#    'geometry': {'type': 'Point', 'coordinates': [-79.413079, 43.6647238]},
#    'properties': {'location_dir_id': 11,
#     'location_name': 'Bloor St W, between Palmerston & Markham (retired)',
#     'direction': 'Westbound',
#     'linear_name_full': 'Bloor St W',
#     'side_street': 'Palmerston Blvd',
#     'centreline_id': 8353520,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': None,
#     'first_active': '2018-02-09',
#     'last_active': '2020-02-11',
#     'date_decommissioned': '2020-02-12',
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 12,
#    'geometry': {'type': 'Point', 'coordinates': [-79.4942429, 43.6490912]},
#    'properties': {'location_dir_id': 12,
#     'location_name': 'Bloor St W, East of Old Mill Trail',
#     'direction': 'Eastbound',
#     'linear_name_full': 'Bloor St W',
#     'side_street': 'Old Mill Trail',
#     'centreline_id': 30081325,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2024-07-31',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 13,
#    'geometry': {'type': 'Point', 'coordinates': [-79.4942979, 43.6491723]},
#    'properties': {'location_dir_id': 13,
#     'location_name': 'Bloor St W, East of Old Mill Trail',
#     'direction': 'Westbound',
#     'linear_name_full': 'Bloor St W',
#     'side_street': 'Old Mill Trail',
#     'centreline_id': 30081325,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2024-10-02',
#     'first_active': '2024-07-31',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 14,
#    'geometry': {'type': 'Point', 'coordinates': [-79.4861368, 43.7444884]},
#    'properties': {'location_dir_id': 14,
#     'location_name': 'Multi-use path south-east of Keele & Sheppard',
#     'direction': 'Northbound',
#     'linear_name_full': 'Keele St',
#     'side_street': 'Sheppard Ave W',
#     'centreline_id': 10133019,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2023-10-18',
#     'first_active': '2022-08-06',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 15,
#    'geometry': {'type': 'Point', 'coordinates': [-79.4861368, 43.7444884]},
#    'properties': {'location_dir_id': 15,
#     'location_name': 'Multi-use path south-east of Keele & Sheppard',
#     'direction': 'Southbound',
#     'linear_name_full': 'Keele St',
#     'side_street': 'Sheppard Ave W',
#     'centreline_id': 10133019,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2023-10-18',
#     'first_active': '2022-08-06',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 16,
#    'geometry': {'type': 'Point', 'coordinates': [-79.4921287, 43.743467]},
#    'properties': {'location_dir_id': 16,
#     'location_name': 'Multi-use path south of Sheppard Ave at Sentinel Rd',
#     'direction': 'Eastbound',
#     'linear_name_full': 'Sheppard Ave W',
#     'side_street': 'Sentinel Rd',
#     'centreline_id': 6002161,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2023-10-18',
#     'first_active': '2023-03-28',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 17,
#    'geometry': {'type': 'Point', 'coordinates': [-79.4921287, 43.743467]},
#    'properties': {'location_dir_id': 17,
#     'location_name': 'Multi-use path south of Sheppard Ave at Sentinel Rd',
#     'direction': 'Westbound',
#     'linear_name_full': 'Sheppard Ave W',
#     'side_street': 'Sentinel Rd',
#     'centreline_id': 6002161,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2023-10-18',
#     'first_active': '2023-03-27',
#     'last_active': '2025-04-01',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 18,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3725671, 43.662038]},
#    'properties': {'location_dir_id': 18,
#     'location_name': 'Sherbourne St, North of Gerrard St',
#     'direction': 'Northbound',
#     'linear_name_full': 'Sherbourne St',
#     'side_street': 'Gerrard St',
#     'centreline_id': 1143580,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2023-10-18',
#     'first_active': '2022-11-14',
#     'last_active': '2025-03-30',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 19,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3725671, 43.662038]},
#    'properties': {'location_dir_id': 19,
#     'location_name': 'Sherbourne St, North of Gerrard St',
#     'direction': 'Southbound',
#     'linear_name_full': 'Sherbourne St',
#     'side_street': 'Gerrard St',
#     'centreline_id': 1143580,
#     'bin_size': '00:15:00',
#     'latest_calibration_study': '2023-10-18',
#     'first_active': '2022-11-14',
#     'last_active': '2025-03-30',
#     'date_decommissioned': None,
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 20,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3725992, 43.6622954]},
#    'properties': {'location_dir_id': 20,
#     'location_name': 'Sherbourne St, North of Gerrard St (retired)',
#     'direction': 'Northbound',
#     'linear_name_full': 'Sherbourne St',
#     'side_street': 'Gerrard St',
#     'centreline_id': 1143580,
#     'bin_size': '01:00:00',
#     'latest_calibration_study': None,
#     'first_active': '2014-04-11',
#     'last_active': '2019-06-02',
#     'date_decommissioned': '2019-06-03',
#     'technology': 'Induction - Eco-Counter'}},
#   {'type': 'Feature',
#    'id': 21,
#    'geometry': {'type': 'Point', 'coordinates': [-79.3725901, 43.661932]},
#    'properties': {'location_dir_id': 21,
#     'location_name': 'Sherbourne St, North of Gerrard St (retired)',
#     'direction': 'Southbound',
#     'linear_name_full': 'Sherbourne St',
#     'side_street': 'Gerrard St',
#     'centreline_id': 1143580,
#     'bin_size': '01:00:00',
#     'latest_calibration_study': None,
#     'first_active': '2015-10-20',
#     'last_active': '2019-02-22',
#     'date_decommissioned': '2019-05-17',
#     'technology': 'Induction - Eco-Counter'}}]}

# %%
#I need to filter the geojson file to only keep the detectors that are in the df_merged file

unique_ids = set(df_merged['location_dir_id'].unique()) #get the unique detector ids. 
#set() is a data type that stores unordered collection of unique elements.

#Filter features to only keep those that are in unique_ids
filtered_features = [
    feature for feature in geojson_data['features']
    if feature['properties']['location_dir_id'] in unique_ids] #location_dir_id, which is within properties in the geojson file

filtered_geojson_data = {'type' : 'FeatureCollection',
                         'features':filtered_features}

with open('filtered_geojson_data', 'w') as f:
    json.dump(filtered_geojson_data, f) #save the filtered geojson data

# %%
#Create map with proper tiles, focusing on Toronto centre, using Toronto coordinates. Smaller zoom number is bigger section of the map
m = folium.Map(location=[43.653963, -79.387207], zoom_start=12,
               tiles = "OpenStreetMap") #explicit base tiles
folium.GeoJson(filtered_geojson_data).add_to(m)

#OpenStreetMap is open-source maps that are made for self-hosting

# %%
#It is best to use Point-based visualization, because bicycle detectors
#are points and do not necessarily indicate the usage of bicycles in the 
#area

# %%
#Create a color scale for my data
min_count = cyclist_data_by_id['sum'].min() #minimum values of cyclists from all the detectors
max_count = cyclist_data_by_id['sum'].max() #maximum values of cyclists from all the detectors
colormap = LinearColormap(
    colors=['blue', 'red'],#color spectrum from blue to red
    vmin=min_count, #blue corresponds to vmin
    vmax=max_count #red corresponds to vmax
)

# %%
# Add colored circles (size and color scaled by count)
for i, row in cyclist_data_by_id.iterrows():
    folium.CircleMarker(
        location=[row['latitude'], row['longitude']],
        radius=row['sum']/max_count * 5 + 5,  # Dynamic radius
        color=colormap(row['sum']),
        fill=True,
        fill_opacity=0.5,
        popup=f"{row['location_name']}: {row['sum']} cyclists, going {row['direction']} "
    ).add_to(m)

# %%
#Add the color scale to the map
colormap.caption = 'Cyclist Count'
colormap.add_to(m)
# Out:
# <svg height="40" width="450"><line x1="0" y1="15" x2="0" y2="27" style="stroke:#0000ffff;stroke-width:2;" /><line x1="1" y1="15" x2="1" y2="27" style="stroke:#0000ffff;stroke-width:2;" /><line x1="2" y1="15" x2="2" y2="27" style="stroke:#0100feff;stroke-width:2;" /><line x1="3" y1="15" x2="3" y2="27" style="stroke:#0100feff;stroke-width:2;" /><line x1="4" y1="15" x2="4" y2="27" style="stroke:#0200fdff;stroke-width:2;" /><line x1="5" y1="15" x2="5" y2="27" style="stroke:#0200fdff;stroke-width:2;" /><line x1="6" y1="15" x2="6" y2="27" style="stroke:#0300fcff;stroke-width:2;" /><line x1="7" y1="15" x2="7" y2="27" style="stroke:#0300fcff;stroke-width:2;" /><line x1="8" y1="15" x2="8" y2="27" style="stroke:#0400fbff;stroke-width:2;" /><line x1="9" y1="15" x2="9" y2="27" style="stroke:#0500faff;stroke-width:2;" /><line x1="10" y1="15" x2="10" y2="27" style="stroke:#0500faff;stroke-width:2;" /><line x1="11" y1="15" x2="11" y2="27" style="stroke:#0600f9ff;stroke-width:2;" /><line x1="12" y1="15" x2="12" y2="27" style="stroke:#0600f9ff;stroke-width:2;" /><line x1="13" y1="15" x2="13" y2="27" style="stroke:#0700f8ff;stroke-width:2;" /><line x1="14" y1="15" x2="14" y2="27" style="stroke:#0700f8ff;stroke-width:2;" /><line x1="15" y1="15" x2="15" y2="27" style="stroke:#0800f7ff;stroke-width:2;" /><line x1="16" y1="15" x2="16" y2="27" style="stroke:#0900f6ff;stroke-width:2;" /><line x1="17" y1="15" x2="17" y2="27" style="stroke:#0900f6ff;stroke-width:2;" /><line x1="18" y1="15" x2="18" y2="27" style="stroke:#0a00f5ff;stroke-width:2;" /><line x1="19" y1="15" x2="19" y2="27" style="stroke:#0a00f5ff;stroke-width:2;" /><line x1="20" y1="15" x2="20" y2="27" style="stroke:#0b00f4ff;stroke-width:2;" /><line x1="21" y1="15" x2="21" y2="27" style="stroke:#0b00f4ff;stroke-width:2;" /><line x1="22" y1="15" x2="22" y2="27" style="stroke:#0c00f3ff;stroke-width:2;" /><line x1="23" y1="15" x2="23" y2="27" style="stroke:#0d00f2ff;stroke-width:2;" /><line x1="24" y1="15" x2="24" y2="27" style="stroke:#0d00f2ff;stroke-width:2;" /><line x1="25" y1="15" x2="25" y2="27" style="stroke:#0e00f1ff;stroke-width:2;" /><line x1="26" y1="15" x2="26" y2="27" style="stroke:#0e00f1ff;stroke-width:2;" /><line x1="27" y1="15" x2="27" y2="27" style="stroke:#0f00f0ff;stroke-width:2;" /><line x1="28" y1="15" x2="28" y2="27" style="stroke:#0f00f0ff;stroke-width:2;" /><line x1="29" y1="15" x2="29" y2="27" style="stroke:#1000efff;stroke-width:2;" /><line x1="30" y1="15" x2="30" y2="27" style="stroke:#1100eeff;stroke-width:2;" /><line x1="31" y1="15" x2="31" y2="27" style="stroke:#1100eeff;stroke-width:2;" /><line x1="32" y1="15" x2="32" y2="27" style="stroke:#1200edff;stroke-width:2;" /><line x1="33" y1="15" x2="33" y2="27" style="stroke:#1200edff;stroke-width:2;" /><line x1="34" y1="15" x2="34" y2="27" style="stroke:#1300ecff;stroke-width:2;" /><line x1="35" y1="15" x2="35" y2="27" style="stroke:#1300ecff;stroke-width:2;" /><line x1="36" y1="15" x2="36" y2="27" style="stroke:#1400ebff;stroke-width:2;" /><line x1="37" y1="15" x2="37" y2="27" style="stroke:#1500eaff;stroke-width:2;" /><line x1="38" y1="15" x2="38" y2="27" style="stroke:#1500eaff;stroke-width:2;" /><line x1="39" y1="15" x2="39" y2="27" style="stroke:#1600e9ff;stroke-width:2;" /><line x1="40" y1="15" x2="40" y2="27" style="stroke:#1600e9ff;stroke-width:2;" /><line x1="41" y1="15" x2="41" y2="27" style="stroke:#1700e8ff;stroke-width:2;" /><line x1="42" y1="15" x2="42" y2="27" style="stroke:#1700e8ff;stroke-width:2;" /><line x1="43" y1="15" x2="43" y2="27" style="stroke:#1800e7ff;stroke-width:2;" /><line x1="44" y1="15" x2="44" y2="27" style="stroke:#1900e6ff;stroke-width:2;" /><line x1="45" y1="15" x2="45" y2="27" style="stroke:#1900e6ff;stroke-width:2;" /><line x1="46" y1="15" x2="46" y2="27" style="stroke:#1a00e5ff;stroke-width:2;" /><line x1="47" y1="15" x2="47" y2="27" style="stroke:#1a00e5ff;stroke-width:2;" /><line x1="48" y1="15" x2="48" y2="27" style="stroke:#1b00e4ff;stroke-width:2;" /><line x1="49" y1="15"  ...

# %%
# Add layer control
folium.LayerControl().add_to(m)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c23cf5659e2d9de646e487ac86bc0fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c23cf5659e2d9de646e487ac86bc0fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c23cf5659e2d9de646e487ac86bc0fb = L.map(
#                 &quot;map_0c23cf5659e2d9de646e487ac86bc0fb&quot;,
#                 {
#                     center: [43.653963, -79.387207],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d19c6f73007a6b9ab5fcdd414486ce3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3d19c6f73007a6b9ab5fcdd414486ce3.addTo(map_0c23cf5659e2d9de646e487ac86bc0fb);
#
#
#
#         function geo_json_410a7bb2a8e5988f2014253722caee5e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_410a7bb2a8e5988f2014253722caee5e = L.geoJson(null, {
#                 onEachFeature: geo_json_410a7bb2a8e5988f2014253722caee5e_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_410a7bb2a8e5988f2014253722caee5e_add (data) {
#             geo_json_410a7bb2a8e5988f2014253722caee5e
#                 .addData(data);
#         }
#             geo_json_410a7bb2a8e5988f2014253722caee5e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [-79.4625696, 43.6541459], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: 3, &quot;properties&quot;: {&quot;bin_size&quot;: &quot;00:15:00&quot;, &quot;centreline_id&quot;: 30042273, &quot;date_decommissioned&quot;: null, &quot;direction&quot;: &quot;Eastbound&quot;, &quot;first_active&quot;: &quot;2023-06-16&quot;, &quot;last_active&quot;: &quot;2025-03-17&quot;, &quot;latest_calibration_study&quot;: &quot;2023-10-18&quot;, &quot;linear_name_full&quot;: &quot;Bloor St W&quot;, &quot;location_dir_id&quot;: 3, &quot;location_name&quot;: &quot;Bloor St W at Oakmount Rd, Display Counter&quot;, &quot;side_street&quot;: &quot;Oakmount Rd&quot;, &quot;technology&quot;: &quot;Induction - Eco-Counter&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-79.375044, 43.6679708], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: 22, &quot;properties&quot;: {&quot;bin_size&quot;: &quot;00:15:00&quot;, &quot;centreline_id&quot;: 10923449, &quot;date_decommissioned&quot;: null, &quot;direction&quot;: &quot;Northbound&quot;, &quot;first_active&quot;: &quot;2022-11-15&quot;, &quot;last_active&quot;: &quot;2025-04-01&quot;, &quot;latest_calibration_study&quot;: &quot;2024-10-02&quot;, &quot;linear_name_full&quot;: &quot;Sherbourne St&quot;, &quot;location_dir_id&quot;: 22, &quot;location_name&quot;: &quot;Sherbourne St, North of Wellesley St E&quot;, &quot;side_street&quot;: &quot;Wellesley St E&quot;, &quot;technology&quot;: &quot;Induction - Eco-Counter&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-79.3868925, 43.6705587], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: 26, &quot;properties&quot;: {&quot;bin_size&quot;: &quot;00:15:00&quot;, &quot;centreline_id&quot;: 11034877, &quot;date_decommissioned&quot;: null, &quot;direction&quot;: &quot;Northbound&quot;, &quot;first_active&quot;: &quot;2022-10-27&quot;, &quot;last_active&quot;: &quot;2025-04-01&quot;, &quot;latest_calibration_study&quot;: &quot;2024-10-02&quot;, &quot;linear_name_full&quot;: &quot;Yonge St&quot;, &quot;location_dir_id&quot;: 26, &quot;location_name&quot;: &quot;Yonge St, North of Bloor St&quot;, &quot;side_street&quot;: &quot;Bloor St&quot;, &quot;technology&quot;: &quot;Induction - Eco-Counter&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-79.3880628, 43.6734429], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: 28, &quot;properties&quot;: {&quot;bin_size&quot;: &quot;00:15:00&quot;, &quot;centreline_id&quot;: 8680067, &quot;date_decommissioned&quot;: null, &quot;direction&quot;: &quot;Northbound&quot;, &quot;first_active&quot;: &quot;2024-01-15&quot;, &quot;last_active&quot;: &quot;2025-04-01&quot;, &quot;latest_calibration_study&quot;: &quot;2024-10-02&quot;, &quot;linear_name_full&quot;: &quot;Yonge St&quot;, &quot;location_dir_id&quot;: 28, &quot;location_name&quot;: &quot;Yonge St, North of Davenport Rd&quot;, &quot;side_street&quot;: &quot;Davenport Rd&quot;, &quot;technology&quot;: &quot;Induction - Eco-Counter&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [-79.3905663, 43.6795414], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: 30, &quot;properties&quot;: {&quot;bin_size&quot;: &quot;00:15:00&quot;, &

# %%
# Save the map
m.save('toronto_bicycle_choropleth.html') #you can change the path so that it saves in your directory of choice
