# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

np.random.seed(613)
x = np.arange(50) # not sure what this does?
y1 = np.random.randint(0, 100, 50)
y2 = np.random.randint(0, 100, 50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1" )
ax.plot(x,y2, label = "Person 2" )
ax.legend(loc = 'upper right')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1" )
ax.plot(x,y2, label = "Person 2" )
ax.legend(loc='lower right',
          frameon = True, # frame around the legend box
          fontsize = 12, 
          ncol = 2, 
          shadow = True) # shadow of the legend box
fig.show()
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_10416\1073276723.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt. subplots(figsize = (5,3))
ax.plot(x,y1, label = "Person 1" )
ax.plot(x,y2, label = "Person 2" )
ax.legend(loc='upper left', # this means the upper left corner of legend box is -->
          bbox_to_anchor = (1,1)) # at (100%, 100%) of our graph
# so if you did bbox_to_anchor = (0.5, 0.5) --> this would be (50%, 50%)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

ax.text(10,95, "This value is important!") 
# we want the text to be at x-value = 10, y-value = 95

ax.text(10, 95, "This value is important!",
 ha ='center', ##alignment of text
 color = 'red', ##modify font colour
 size = 20) ##modify font size

fig.show() 
# in jupyter notebook, you don't need to enter this but DSI did these slides on web-hosted
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_10416\2430636870.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots()
ax.axis([0, 10, # x-axis range
          0, 10]) # y-axis range

ax.text(1, 5, ". Data:(1, 5)", transform=ax.transData ) # not sure how we change the code for data though...?
ax.text(0.5, 0.1, ". Axes:(0.5, 0.1)", transform=ax.transAxes ) 
ax.text(0.2, 0.2, ". Figure:(0.2, 0.2)", transform=fig.transFigure ) # changing what we're referring to --> 20% of Figure
# Out:
# Text(0.2, 0.2, '. Figure:(0.2, 0.2)')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc = 'lower right')
ax.annotate('This is important!',
            xy = (10, 95), 
            xytext = (20, 94),
            arrowprops = dict(arrowstyle = "wedge", facecolor = "hotpink")
            )
# Out:
# Text(20, 94, 'This is important!')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

ax.yaxis.set_major_locator(plt.NullLocator()) # Use locator to remove ticks and labels; 

ax.xaxis.set_major_formatter(plt.NullFormatter()) # Use formatter to remove only labels

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

ax.xaxis.set_major_locator(plt.MaxNLocator(2)) # you can change the number of tick marks on our axis

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

ax.xaxis.set_major_locator(plt.MultipleLocator(5)) # We can set tick marks at a particular interval (in this case, 5)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

plt.xticks(rotation = 45, ha = 'right', fontsize=12, font = 'serif') 
# you can rotate tick marks, and customize font too (size 12, font style serif)
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
font1 = {'family': 'serif', 'color': 'purple'}

fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

plt.xticks(rotation = 45, ha = 'right', fontsize=12, font = 'serif') 
# you can rotate tick marks, and customize font too (size 12, font style serif)
plt.xlabel('Shiny New Axis!', fontsize = 18, fontdict = font1)
# Out:
# Text(0.5, 0, 'Shiny New Axis!')

# %%
plt.style.available # this is all the themes we can use
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-v0_8-bright') # or you can use 'default'
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1)

# once you use a certain style, it'll use the same style through the whole notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0, 75,50)
x2 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y2 = np.array([110, 180, 240, 99, 220])

# %%
y1
# Out:
# array([11, 26, 60, 55, 50,  6, 21, 49, 58, 43, 62, 25, 42, 54, 12, 16, 43,
#        14, 39, 69, 41, 68, 56, 55, 39, 50, 41, 22, 50, 48, 70, 21, 16, 23,
#         0, 55, 36, 20, 37, 22, 13, 17, 50, 32,  0, 58, 59, 15, 27, 53])

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2, # number of columns we want
 nrows=1, # # of rows we want = 1
 figsize=(7, 3))

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2,
 nrows=1,
 figsize=(7, 3))
ax1.scatter(x1,y1, label = 'happiness')
ax2.bar(x2,y2, label = 'boom')
ax.legend(loc = 'upper right')
# Out:
# C:\Users\preet\AppData\Local\Temp\ipykernel_10416\233445608.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc = 'upper right')

# %%
fig, someaxes = plt.subplot_mosaic(
 [['ax1', 'ax3'], # someaxes = total axes
 ['ax2', 'ax3']],
 figsize=(7, 4)
 )

# why does this set the placement and size?

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
                                    ['ax2', 'ax3']], 
                                    # above line of code basically divides the figure into 4 quarters, 
                                    # and that's how we have the different sizes
 figsize=(7, 4))
someaxes["ax1"].scatter(x1,y1)
# someaxes = the overall group of axes and by referencing ['ax1'], we are just referring to ax1 in someaxes
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
plt.show()

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
 ['ax2', 'ax3']],
 figsize=(7, 4)) 
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

someaxes["ax1"].set_xlabel('A Big Label',fontsize=18)
someaxes["ax2"].set_xlabel('Another Label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 Fast 2 Furious',fontsize=18 )

# labels disappear or are cut off... how do we fix this? next slide
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'], ['ax2', 'ax3']], figsize=(7, 4), layout = "constrained")
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)

someaxes["ax1"].set_xlabel('A Big Label',fontsize=18)
someaxes["ax2"].set_xlabel('Another Label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 Fast 2 Furious',fontsize=18 )
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
fig, someaxes = plt.subplot_mosaic([['ax1', 'ax3'],
 ['ax2', 'ax3']],
 figsize=(7, 4)) 
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
someaxes["ax1"].set_xlabel('A Big Label',fontsize=18)
someaxes["ax2"].set_xlabel('Another Label',fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 Fast 2 Furious',fontsize=18 )
# Out:
# Text(0.5, 0, 'Label 2: 2 Fast 2 Furious')

# %%
# first make our sample data
x = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])
# define our figure and axes (just one this time)
fig, ax = plt.subplots(figsize=(7, 3))
# now call both bar and plot elements to the same axes (ax)
ax.bar(x, y1,
color = "indigo")
ax.plot(x, y2,
color = "red")

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x, y2, color = 'red')

# %%
y2_sd = np.std(y2)

fig, ax = plt.subplots(figsize=(7,3))
ax.plot(x, y2, color = 'red')

ax.errorbar(x, # our x values
 y2, # our y values
 yerr = y2_sd,
 fmt = "none") # keeps lines vs. error bars separate
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2,
 color = "blue")
ax.errorbar(x,
 y2,
 yerr = y2_sd,
 fmt = "none",
 ecolor= "grey",
 elinewidth= 4,
 capsize = 5,
 capthick= 4 )
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2,
 color = "blue")
ax.errorbar(x,
 y2,
 yerr = y2_sd,
 fmt = "none",
 ecolor= "grey",
 elinewidth= 4,
 capsize = 5,
 capthick= 4,
 errorevery = 2 )
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
from PIL import Image # to open images
import requests # to get images from URLs
from io import BytesIO # to store images

response = requests.get('https://static.wikia.nocookie.net/the-ultimate-good/images/3/3d/Luffy.png/revision/latest?cb=20230417200546')
image_file = BytesIO(response.content)
image = Image.open (image_file)

# %%
fig, ax = plt.subplots(figsize = (7,3))
ax.plot(x, y2, color = 'red')

ax_image = fig.add_axes([0.1, 0.11, # location of image
                         0.15, 0.3]) # dimensions/size of image

ax_image.imshow(image)
ax_image.axis('off')
# Out:
# (-0.5, 410.5, 999.5, -0.5)
