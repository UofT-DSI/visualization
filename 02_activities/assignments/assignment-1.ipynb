# %% [markdown]
# SESSION 1:
#
# Part 1 of Session 1:
#
#
#
# In the first part of this session, the instructor presented several data visualizations. The task was to critically evaluate these visualizations based on their effectiveness, clarity, and adherence to design principles. We assessed whether the visualizations successfully convey the intended message and identify areas for improvement. This exercise aims to develop our ability to discern high-quality visualizations and apply best practices in data visualization.
#
#
#
#
#
# Part 2 of Session 1:
#
# In the second part of the session, we explored various data visualization tools:
#
# Excel:
#
# Description: Spreadsheet software with basic charting features.
# Strengths: Easy to use, good for quick and simple charts.
# Limitations: Limited advanced options and scalability.
#
#
# Tableau:
#
# Description: Advanced tool for interactive and shareable dashboards.
# Strengths: Interactive visuals, connects to multiple data sources.
# Limitations: Can be costly, steep learning curve for advanced features.
#
#
# Power BI:
#
# Description: Microsoft’s tool for interactive visualizations and reporting.
# Strengths: Integrates with Microsoft products, user-friendly.
# Limitations: Some features require higher-tier plans.
#
#
# R:
#
# Description: Programming language with extensive visualization libraries.
# Strengths: Customizable, strong statistical capabilities.
# Limitations: Requires programming knowledge.
#
#
# Python:
#
# Description: Versatile language with libraries like Matplotlib and Seaborn.
# Strengths: Flexible, integrates with data tools.
# Limitations: Requires programming skills.
#
#
#
#
#
#
#
#
#
# Part 3 of Session 1:
#
# Matplotlib:
#
# Description: Matplotlib is a widely-used Python library for creating static, interactive, and animated visualizations. It provides a flexible and comprehensive suite of tools for generating plots and charts.
# Strengths: Highly customizable, supports a wide range of visualizations (e.g., line plots, bar charts, histograms), integrates well with other Python libraries like Pandas.
# Limitations: Basic visualizations can be verbose to code, advanced features may require additional libraries (e.g., Seaborn for statistical plots).
#
# Then, we started coding:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# %%
import numpy as np

# Set the random seed for reproducibility
np.random.seed(613)

# Create an array of 50 sequential integers
x = np.arange(50)

# Generate an array of 50 random integers between 0 and 100
y = np.random.randint(0, 100, 50)

# %%
# Create a figure and a set of subplots with a specified size
fig, ax = plt.subplots(figsize=(5, 3))

# Create a scatter plot on the specified axes
ax.scatter(x, y)

# %%
# Create a figure and a set of subplots with a specified size
fig, ax = plt.subplots(figsize=(5, 3))

# Create a bar plot on the specified axes
ax.bar(x, y)
# Out:
# <BarContainer object of 50 artists>

# %%
# Create a figure and a set of subplots with a specified size
fig, ax = plt.subplots(figsize=(5, 3))

# Create a line plot on the specified axes
ax.plot(x, y)

# %%
## CHALLENGE: change to histogram

# Create a figure and a set of subplots with a specified size
fig, ax = plt.subplots(figsize=(5, 3))

# Create a histogram of the y values on the specified axes
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
# Create a figure and a set of subplots with a specified size
fig, ax = plt.subplots(figsize=(5, 3))

# Create a line plot on the specified axes
ax.plot(x, y)

# Set the title of the plot
ax.set_title('Total growth over time')

# Set the label for the y-axis
ax.set_ylabel('Total growth')

# Set the label for the x-axis
ax.set_xlabel('Years since start')

# Adjust layout to fit labels and titles
fig.tight_layout()

# %%
# Define font properties for the title and labels
font1 = {'family': 'sans-serif', 'color': 'blue', 'size': 20}
font2 = {'family': 'monospace', 'color': 'green', 'size': 14}

# Create a figure and a set of subplots with a specified size
fig, ax = plt.subplots(figsize=(5, 3))

# Create a line plot on the specified axes
ax.plot(x, y)

# Set the title of the plot with specified font properties
ax.set_title('Total Growth Over Time', fontdict=font1)

# Set the label for the y-axis with specified font properties
ax.set_ylabel('Total Growth', fontdict=font2)

# Set the label for the x-axis with specified font properties
ax.set_xlabel('Years Since Start', fontdict=font2)
# Out:
# Text(0.5, 0, 'Years since start')

# %%
# Create a figure and a set of subplots with a specified size
fig, ax = plt.subplots(figsize=(5, 3))

# Create a scatter plot with specified marker and color
ax.scatter(x, y, marker='*', color='indigo')  # NEW ADDITIONS

# Display the plot
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5464\2130643811.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Create a figure and a set of subplots with a specified size
fig, ax = plt.subplots(figsize=(5, 3))

# Create a line plot with specified marker, color, linestyle, and linewidth
ax.plot(x, y, marker='*', color='indigo', linestyle='--', linewidth=2)  # NEW ADDITIONS

# Display the plot
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5464\1577294754.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Create a figure and a set of subplots with a specified size
fig, ax = plt.subplots(figsize=(5, 3))

# Create a line plot with specified marker, color, linestyle, linewidth, and marker properties
ax.plot(
    x, y, 
    marker='*',             # Marker type
    markersize=12,          # Size of the marker
    color='#7425b9',       # Line color
    linestyle='--',        # Line style
    linewidth=2,          # Line width
    markeredgecolor='#fa9359', # Marker edge color
    markerfacecolor='#000000'  # Marker face color
)

# Display the plot
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_5464\682142647.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Create a figure and a set of subplots with a specified size
fig, ax = plt.subplots(figsize=(5, 3))

# Create a line plot with specified marker, color, linestyle, linewidth, and marker properties
ax.plot(
    x, y, 
    marker='*',             # Marker type
    markersize=12,          # Size of the marker
    color='#7425b9',       # Line color
    linestyle='--',        # Line style
    linewidth=2,          # Line width
    markeredgecolor='#fa9359', # Marker edge color
    markerfacecolor='#000000'  # Marker face color
)

# Add a grid with specified color, linewidth, and linestyle
ax.grid(color='pink', linewidth=4, linestyle='dotted')

# %% [markdown]
# SESSION 2: In the first part of this session, the instructor explained how reproducibility in data visualization is crucial. Reproducinility ensures that visual findings can be consistently recreated and verified by others. This builds trust in the results and allows for accurate comparison and validation of data over time. To comply with reproducibility, it's important to document the data sources, visualization steps, and any transformations applied to the data. Using standardized tools and formats, such as saving scripts in Python or templates in Tableau, helps maintain consistency. Sharing both the data and the code or methods used for visualization enables others to reproduce the visualizations accurately, fostering transparency and reliability in data analysis.
#
# The instructor then asked us to comment our codes and I did this.
#
# In the second part, the concepts of neutrality and objectivity are introduced. Neutrality ensures that the visualization does not mislead or distort data, maintaining a balanced representation of the facts. Objectivity involves presenting data in a way that is free from personal or subjective interpretations, allowing the data to speak for itself. Understanding how different elements and types of visualizations are perceived helps in choosing the most appropriate format for a given situation. For example, bar charts are often used to compare discrete categories, while line charts are ideal for showing trends over time. Pie charts might represent proportions but can be misleading with too many categories. By selecting the right type of visualization, you ensure that the data is presented clearly and effectively, supporting informed decision-making without imparting unintended bias.
#
# The perception of data visualization is also significantly influenced by cognitive factors:
#
# -Clarity: Visualizations that are clear and straightforward help viewers quickly understand the information. Well-labeled charts with appropriate scales and legends are perceived as more effective and trustworthy.
#
# -Accuracy: Accurate visualizations, free from distortion or misleading elements, are seen as credible. Issues such as scaling problems or truncated axes can lead to misinterpretation.
#
# -Simplicity: Simple and straightforward visualizations are generally easier to interpret. Overly complex or cluttered visuals can overwhelm or confuse viewers, making cognitive processing more difficult.
#
# -Bias: Visualizations that introduce bias through design choices (e.g., selective data highlighting) can mislead viewers. Neutral and balanced visualizations help maintain cognitive integrity and prevent skewed interpretations.
#
# -Cognitive Load: Visualizations should consider cognitive load, the amount of mental effort required to process information. Well-designed visualizations reduce cognitive load by presenting data in an intuitive way, making it easier for viewers to understand and retain information.

# %% [markdown]
# SESSION 3:

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)

# %%
# try to plot both y variables on the same axis

fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2892\1181431450.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1" )
ax.plot(x,y2, label = "Person 2" )
ax.legend(loc='lower right')
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2892\3769157663.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='lower right'
,
frameon = True, #add frame around the legend
fontsize = 12, #change font size
ncol = 2, #specify number of columns
shadow = True )
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2892\4170007742.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='upper left'
,
bbox_to_anchor =(1, 1))
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2892\2747934926.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.text(10, 95,
"This value is important!")
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2892\2434332038.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.text(10, 95,
"Some random words!"
,
ha='center'
, ##alignment of text
color = 'red'
, ##modify font colour
size = 20) ##modify font size
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2892\2182629833.py:13: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])
ax.text(1, 5,
". Data:(1, 5)"
, transform=ax.transData )
ax.text(0.5, 0.1,
". Axes:(0.5, 0.1)"
, transform=ax.transAxes )
ax.text(0.2, 0.2,
". Figure:(0.2, 0.2)"
, transform=fig.transFigure )
# Out:
# Text(0.2, 0.2, '. Figure:(0.2, 0.2)')

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.annotate('This is important!'
, xy=(10, 95), xytext=(20, 94),
arrowprops=dict(facecolor='black'
, shrink=0.05))
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2892\600220611.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')

ax.annotate('This is important!'
,
xy=(10, 95), xytext=(20, 94),
arrowprops = dict(arrowstyle = "wedge"
,
color = 'hotpink'))
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2892\3848410680.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MaxNLocator(3))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax.xaxis.set_major_locator(plt.MultipleLocator(5))

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xticks(rotation=45, ha='right')
# Out:
# (array([-10.,   0.,  10.,  20.,  30.,  40.,  50.,  60.]),
#  [Text(-10.0, 0, '−10'),
#   Text(0.0, 0, '0'),
#   Text(10.0, 0, '10'),
#   Text(20.0, 0, '20'),
#   Text(30.0, 0, '30'),
#   Text(40.0, 0, '40'),
#   Text(50.0, 0, '50'),
#   Text(60.0, 0, '60')])

# %%
font1 = {'family':'serif'
,
'color':'indigo'}
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xlabel('Shiny New X Axis!'
, fontsize = 18, fontdict = font1)
# Out:
# Text(0.5, 0, 'Shiny New X Axis!')

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2892\819060809.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
plt.style.use('classic')
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2892\1798479455.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0, 75,50)
x2 = np.array(["Luffy"
,
"Zoro"
,
"Nami"
,
"Usopp"
,
"Sanji"])
y2 = np.array([110, 180, 240, 99, 220])

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2,
nrows=1,
figsize=(7, 3))
ax1.scatter(x1,y1)
ax2.bar(x2,y2)
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2892\3211146341.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig,(ax1, ax2) = plt.subplots(ncols=2,
nrows=1,
figsize=(9, 3))
font1={'family': 'serif', 'size':14}
ax1.scatter(x1,y1,marker='o',color='red')
ax2.bar(x2,y2,color='darkgreen')
ax1.set_title('Scatterplot!',fontdict=font1)
ax2.set_title('Barplot!',fontdict=font1)
fig.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_2892\3499288709.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, someaxes = plt.subplot_mosaic([['ax1'
,
'ax3'],
['ax2'
,
'ax3']],
figsize=(7, 4))
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
plt.show()

# %%
fig, someaxes = plt.subplot_mosaic([['ax1'
,
'ax3'],
['ax2'
,
'ax3']],
figsize=(7, 4))
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
someaxes["ax1"].set_xlabel('A Big Label'
,fontsize=18)
someaxes["ax2"].set_xlabel('Another Label'
,fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 Fast 2 Furious'
,fontsize=18 )
plt.show()

# %%
fig, someaxes = plt.subplot_mosaic([['ax1'
,
'ax3'],
['ax2'
,
'ax3']],
figsize=(7, 4),
layout = "constrained")
someaxes["ax1"].scatter(x1,y1)
someaxes["ax2"].bar(x2,y2)
someaxes["ax3"].plot(x1,y1)
someaxes["ax1"].set_xlabel('A Big Label'
, fontsize=18)
someaxes["ax2"].set_xlabel('Another Label'
, fontsize=18)
someaxes["ax3"].set_xlabel('Label 2: 2 Fast 2 Furious'
, fontsize=18)
plt.show()

# %%
# first make our sample data
x = np.array(["Luffy"
,
"Zoro"
,
"Nami"
,
"Usopp"
,
"Sanji"])
y1 = np.array([110, 180, 240, 99, 220])
y2 = np.array([170, 100, 90, 120, 50])
# define our figure and axes (just one this time)
fig, ax = plt.subplots(figsize=(7, 3))
# now call both bar and plot elements to the same axes (ax)
ax.bar(x, y1,
color = "indigo")
ax.plot(x, y2,
color = "red")

# %%
y2_sd = np.std(y2)
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")

ax.errorbar(x, #our x values
y2, #our y values
yerr = y2_sd,
fmt = "none")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
y2_sd = np.std(y2)
fig, ax = plt.subplots(figsize=(7, 3))
ax.plot(x, y2, color = "red")

ax.errorbar(x,y2,
yerr=y2_sd,
fmt="none",
ecolor="indigo",
elinewidth=4,
capsize=6,
capthick=4)
# Out:
# <ErrorbarContainer object of 3 artists>
