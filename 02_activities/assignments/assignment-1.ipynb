# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
np.random.seed(613) # set seed
x = np.arange(50) # 0,1,...,49
y = np.random.randint(0,100,50) # 50 random integers with min = 0, max = 99

# %%
fig,ax = plt.subplots(figsize=(5,3)) # figure size
ax.scatter(x,y)
# Out:
# Error in callback <function _draw_all_if_interactive at 0x000001BB325364C0> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\pyplot.py:268, in _draw_all_if_interactive()
#     266 def _draw_all_if_interactive() -> None:
#     267     if matplotlib.is_interactive():
# --> 268         draw_all()
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\_pylab_helpers.py:131, in Gcf.draw_all(cls, force)
#     129 for manager in cls.get_all_fig_managers():
#     130     if force or manager.canvas.figure.stale:
# --> 131         manager.canvas.draw_idle()
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\backend_bases.py:1905, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1903 if not self._is_idle_drawing:
#    1904     with self._idle_draw_cntx():
# -> 1905         self.draw(*args, **kwargs)
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\backends\backend_agg.py:387, in FigureCanvasAgg.draw(self)
#     384 # Acquire a lock on the shared font cache.
#     385 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     386       else nullcontext()):
# --> 387     self.figure.draw(self.renderer)
#     388     # A GUI class may be need to update a window using this draw, so
#     389     # don't forget to call the superclass.
#     390     super().draw()
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\axes\_base.py:3143, in _AxesBase.draw(self, renderer)
#    3140 if artists_rasterized:
#    3141     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3143 mimage._draw_list_compositing_images(
#    3144     renderer, self, artists, self.figure.suppressComposite)
#    3146 renderer.close_group('axes')
#    3147 self.stale = False
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\axis.py:1422, in Axis.draw(self, renderer)
#    1419     return
#    1420 renderer.open_group(__name__, gid=self.get_gid())
# -> 1422 ticks_to_draw = self._update_ticks()
#    1423 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1425 for tick in ticks_to_draw:
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\axis.py:1299, in Axis._update_ticks(self)
#    1294 def _update_ticks(self):
#    1295     """
#    1296     Update ticks (position and labels) using the current data interval of
#    1297     the axes.  Return the list of ticks that will be drawn.
#    1298     """
# -> 1299     major_locs = self.get_majorticklocs()
#    1300     major_labels = self.major.formatter.format_ticks(major_locs)
#    1301     major_ticks = self.get_major_ticks(len(major_locs))
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\axis.py:1530, in Axis.get_majorticklocs(self)
#    1528 def get_majorticklocs(self):
#    1529     """Return this Axis' major tick locations in data coordinates."""
# -> 1530     return self.major.locator()
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\ticker.py:2171, in MaxNLocator.__call__(self)
#    2169 def __call__(self):
#    2170     vmin, vmax = self.axis.get_view_interval()
# -> 2171     return self.tick_values(vmin, vmax)
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\ticker.py:2179, in MaxNLocator.tick_values(self, vmin, vmax)
#    2176     vmin = -vmax
#    2177 vmin, vmax = mtransforms.nonsingular(
#    2178     vmin, vmax, expander=1e-13, tiny=1e-14)
# -> 2179 locs = self._raw_ticks(vmin, vmax)
#    2181 prune = self._prune
#    2182 if prune == 'lower':
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\ticker.py:2109, in MaxNLocator._raw_ticks(self, vmin, vmax)
#    2107 if self._nbins == 'auto':
#    2108     if self.axis is not None:
# -> 2109         nbins = np.clip(self.axis.get_tick_space(),
#    2110                         max(1, self._min_n_ticks - 1), 9)
#    2111     else:
#    2112         nbins = 9
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\axis.py:2552, in XAxis.get_tick_space(self)
#    2550 def get_tick_space(self):
#    2551     ends = mtransforms.Bbox.unit().transformed(
# -> 2552         self.axes.transAxes - self.figure.dpi_scale_trans)
#    2553     length = ends.width * 72
#    2554     # There is a heuristic here that the aspect ratio of tick text
#    2555     # is no more than 3:1
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\transforms.py:1472, in Transform.__sub__(self, other)
#    1470 # if we have got this far, then there was no shortcut possible
#    1471 if other.has_inverse:
# -> 1472     return self + other.inverted()
#    1473 else:
#    1474     raise ValueError('It is not possible to compute transA - transB '
#    1475                      'since transB cannot be inverted and there is no '
#    1476                      'shortcut possible.')
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\matplotlib\transforms.py:1889, in Affine2DBase.inverted(self)
#    1887     if self._shorthand_name:
#    1888         shorthand_name = '(%s)-1' % self._shorthand_name
# -> 1889     self._inverted = Affine2D(inv(mtx), shorthand_name=shorthand_name)
#    1890     self._invalid = 0
#    1891 return self._inverted
#
# File c:\Users\Gulru\miniconda3\envs\dsi_participant\lib\site-packages\numpy\linalg\linalg.py:562, in inv(a)
#     560 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
#     561 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
# --> 562 return wrap(ainv.astype(result_t, copy=False))
#
# KeyboardInterrupt:

# %%
ax.bar(x,y)
# Out:
# <BarContainer object of 50 artists>

# %%
ax.plot(x,y)

# %%
ax.hist(y)
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
fig,ax = plt.subplots(figsize=(5,3)) 
ax.plot(x,y)

ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
# Out:
# Text(0.5, 0, 'Years since start')

# %%
fig,ax = plt.subplots(figsize=(5,3)) 
ax.scatter(x,y,
          marker = '*', # >, +, etc
          color = 'indigo')
linestye = '--',
linewidth = 2,
markersize = 12,
markeredgecolor = '#fa9359',
markerfacecolor = 'black'
