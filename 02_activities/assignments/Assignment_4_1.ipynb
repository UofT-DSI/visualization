# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\jolin\Downloads\bridge_condition_open_data_2020_en.csv")

# %%
# Filter the data for Culverts
culverts_df = df[df['CATEGORY'] == 'Culvert']
culverts_df.columns
# Out:
# Index(['ID (SITE N°)', 'STRUCTURE NAME', 'FRENCH NAME', 'HIGHWAY NAME',
#        'LATITUDE', 'LONGITUDE', 'CATEGORY', 'SUBCATEGORY 1', 'TYPE 1',
#        'MATERIAL 1', 'YEAR BUILT', 'LAST MAJOR REHAB', 'LAST MINOR REHAB',
#        'NUMBER OF SPAN / CELLS', 'SPAN DETAILS (m)',
#        'DECK / CULVERTS LENGTH (m)', 'WIDTH TOTAL (m)', 'REGION', 'COUNTY',
#        'OPERATION STATUS', 'OWNER', 'LAST INSPECTION DATE', 'CURRENT BCI',
#        '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012',
#        '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003',
#        '2002', '2001', '2000'],
#       dtype='object')

# %%
culverts_df
# Out:
#      ID (SITE N°)            STRUCTURE NAME FRENCH NAME HIGHWAY NAME  \
# 0     01X-0018/C0                Culvert 18         NaN          403
# 1     01X-0019/C0                Culvert 19         NaN          403
# 31    01X-0197/C0     CULVERT AT GARDEN AVE         NaN          403
# 32    01X-0204/C0               CULVERT 204         NaN           24
# 33    01X-0205/C0               CULVERT 205         NaN           24
# ...           ...                       ...         ...          ...
# 5047  49X-0070/C0       BURNT CREEK CULVERT         NaN          540
# 5048  49X-0071/C0     WITTY'S CREEK CULVERT         NaN          540
# 5049  49X-0072/C0          ICE LAKE CULVERT         NaN          540
# 5051  49X-0074/C0  WAKAWAGAMI CREEK CULVERT         NaN            6
# 5052  49X-0075/C0            UNAMED CULVERT         NaN          542
#
#        LATITUDE  LONGITUDE CATEGORY   SUBCATEGORY 1  \
# 0     43.167542 -80.215807  Culvert  Closed Culvert
# ...

# %%
df_long = pd.melt(culverts_df, id_vars=['ID (SITE N°)', 'STRUCTURE NAME', 'FRENCH NAME', 'HIGHWAY NAME',
       'LATITUDE', 'LONGITUDE', 'CATEGORY', 'SUBCATEGORY 1', 'TYPE 1',
       'MATERIAL 1', 'YEAR BUILT', 'LAST MAJOR REHAB', 'LAST MINOR REHAB',
       'NUMBER OF SPAN / CELLS', 'SPAN DETAILS (m)',
       'DECK / CULVERTS LENGTH (m)', 'WIDTH TOTAL (m)', 'REGION', 'COUNTY',
       'OPERATION STATUS', 'OWNER', 'LAST INSPECTION DATE'], var_name = 'Year', value_name='BCI_Value')
# df_long = df_long.dropna()

# df_long['Year'] = pd.Categorical(df_long['Year'], categories=['CURRENT BCI',
#        '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012',
#        '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003',
#        '2002', '2001', '2000'], ordered=True)

# %%
df_long.head(10)
# Out:
#   ID (SITE N°)                   STRUCTURE NAME FRENCH NAME HIGHWAY NAME  \
# 0  01X-0018/C0                       Culvert 18         NaN          403
# 1  01X-0019/C0                       Culvert 19         NaN          403
# 2  01X-0197/C0            CULVERT AT GARDEN AVE         NaN          403
# 3  01X-0204/C0                      CULVERT 204         NaN           24
# 4  01X-0205/C0                      CULVERT 205         NaN           24
# 5  01X-0219/C0                      CULVERT 219         NaN          403
# 6  01X-0220/C0                      CULVERT 220         NaN          403
# 7  01X-0221/C0  Culvert (1.4 km west of Rd. 16)         NaN          403
# 8  01X-0224/C0                      CULVERT 224         NaN          403
# 9  01X-0314/C0          N-S Farm Access Culvert         NaN          403
#
#     LATITUDE  LONGITUDE CATEGORY   SUBCATEGORY 1                      TYPE 1  \
# 0  43.167542 -80.215807  Culvert  Closed Culvert   Box Culvert (Rigid Frame)
# ...

# %%
# plot
plt.figure(figsize = (18,10))
plt.scatter (df_long['Year'], df_long['BCI_Value'], s=15, alpha=0.5, edgecolors='w')

plt.xlabel('Year')
plt.ylabel('BCI Value(%)')
plt.title('BCI over the years for Culverts')

plt.xticks(rotation=90)

plt.tight_layout()
plt.show()
