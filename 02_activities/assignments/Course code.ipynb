# %% [markdown]
# <a href="https://colab.research.google.com/github/M7office/visualization/blob/assignment-1/Course%20code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
###################################################
# course 1 : notes
###################################################
Good viz examples:
- plotting black bars at the locations of each cholera death ->  tracing an outbreak
- rose diagram -> to advocate for prioritizing nutrition, ventilation, and shelter, revolutionizing army medicine
- Figurative Map of the successive losses

Good viz:
- pleasing to look at
- accurately and honestly present data
- understand what message is attempting to convey

Tools for viz:
- Tableau
- Microsoft Power BI
- R
- Python

Basic:
- Matplotlib -> make a plot
  - figure is a container that holds axes
  - visual element belongs to an axes not to a figure


Getting fancy:
- Seaborn
- Plotly -> interactive viz
- WordCloud -> Qualitative viz

# usefull links:
# https://matplotlib.org/cheatsheets/
# https://python-graph-gallery.com/all-charts/
# https://python-graph-gallery.com/color-palette-finder/
# https://matplotlib.org/stable/users/explain/colors/colormaps.html  (Viridis package: colourblindness)
# https://media.datacamp.com/legacy/image/upload/v1676302629/Marketing/Blog/Seaborn_Cheat_Sheet.pdf
# https://seaborn.pydata.org/examples/index.html (nice)

# %%
########################################################
# Course 2: basic figures using matplotlib
########################################################

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# basic figurs
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0, 100, 50)

fig, ax = plt.subplots(figsize=(5,3))
ax.scatter(x, y)

fig, ax = plt.subplots(figsize=(5,3))
ax.bar(x, y)

ax.set_title('Total growth over time')
ax.set_ylabel('Total growth')
ax.set_xlabel('Years since start')
fig.tight_layout()

# modify our labels and titles’ appearance by using font dictionaries (‘fontdict’)
font1 = {'family':'sans-serif', 'color':'blue', 'size':20}
font2 = {'family':'monospace', 'color':'green', 'size':14}

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x, y)

ax.set_title('Total growth over time', fontdict=font1)
ax.set_ylabel('Total growth', fontdict=font2)
ax.set_xlabel('Years since start', fontdict=font2)
fig.tight_layout()

# markers
ax.plot(
    x,
    y,
    marker='*',
    markersize=12,

    color='#7425b9',
    linestyle='--',
    linewidth=2,

    markeredgecolor='#fa9359',
    markerfacecolor='#000000'
)

# add grid
ax.grid(
    axis='y',
    color='blue',
    linewidth=2,
    linestyle='--'
)

fig.show()

# %%
################################################
# course 3: annotations
################################################
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# legends
np.random.seed(613)
x = np.arange(50)

y1 = np.random.randint(0, 100, 50)
y2 = np.random.randint(0, 100, 50)

fig, ax = plt.subplots(figsize=(5, 3))

ax.plot(x, y1, label='Person 1')
ax.plot(x, y2, label='Person 2')

ax.legend(
    loc='lower right',
    frameon=True,
    fontsize=12,
    ncol=2,
    shadow=True
)


fig, ax = plt.subplots(figsize=(5, 3))

ax.plot(x, y1, label='Person 1')
ax.plot(x, y2, label='Person 2')

ax.legend(
    loc='upper left',
    bbox_to_anchor=(1, 1)
)


# add texts
fig, ax = plt.subplots(figsize=(5, 3))

ax.scatter(x, y1, label='Person 1')
ax.scatter(x, y2, label='Person 2')

ax.legend(loc='lower right')

ax.text(
    10,
    95,
    "This value is important!",
    ha='center',
    color='red',
    size=20
)

# modify text location
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10])

ax.text(1, 5, ". Data: (1, 5)", transform=ax.transData)
ax.text(0.5, 0.1, ". Axis: (0.5, 0.1)", transform=ax.transAxes)
ax.text(0.2, 0.2, ". Figure: (0.2, 0.2)", transform=fig.transFigure)

# add arrows
fig, ax = plt.subplots(figsize=(5, 3))

ax.scatter(x, y1, label="Person 1")
ax.scatter(x, y2, label="Person 2")

ax.legend(loc='lower right')
ax.annotate(
    'This is important!',
    xy=(10, 95),
    xytext=(20, 94),
    arrowprops=dict(facecolor='black')
)

# ax.yaxis.set_major_locator  and .set_major_formatter: no ticks or ticklabels on axis
fig, ax = plt.subplots(figsize=(5, 3))

ax.scatter(x, y1, label="Person 1")
ax.scatter(x, y2, label="Person 2")

ax.legend(loc='lower right')

ax.yaxis.set_major_locator(plt.NullLocator())
ax.xaxis.set_major_formatter(plt.NullFormatter())

# ax.xaxis.set_major_locator and plt.xticks : modify xaxis and yaxis ticks
fig, ax = plt.subplots(figsize=(5, 3))

ax.scatter(x, y1, label="Person 1")
ax.scatter(x, y2, label="Person 2")

ax.legend(loc='lower right')

ax.xaxis.set_major_locator(plt.MaxNLocator(3))

plt.xticks(rotation=45, ha='right')

# plt.xlabel or ax.set_xlabel:  modify xlabel appearance using fontdict
font1 = {'family':'serif', 'color':'indigo'}

fig, ax = plt.subplots(figsize=(5, 3))

ax.scatter(x, y1, label="Person 1")
ax.scatter(x, y2, label="Person 2")

ax.legend(loc='lower right')

ax.set_xlabel('Shiny New X Axis!', fontsize=18, fontdict=font1)
# Out:
# Text(0.5, 0, 'Shiny New X Axis!')

# %%
#################################################
# course 4: subplots
##################################################
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests


# sub axas
np.random.seed(613)
x1 = np.arange(50)
y1 = np.random.randint(0,75,50)

x2 = np.array(['Luffy','Zoro','Nami','Usopp','Sanji'])
y2 = np.array([110,180,240,99,220])

fig, (ax1,ax2) = plt.subplots(ncols =2, nrows = 1, figsize=(7,3))

ax1.scatter(x1,y1)
ax1.annotate('this is important',xy=(10,60),xytext=(20,60),arrowprops=dict(facecolor='black'))
ax2.bar(x2,y2)
fig.show()

fig,someaxes = plt.subplot_mosaic([['ax1','ax3'],
                                   ['ax2','ax3']],
                                  figsize=(7,4),
                                  layout = 'constrained')

someaxes['ax1'].scatter(x1,y1)
someaxes['ax2'].bar(x2,y2)
someaxes['ax3'].plot(x1,y1)

someaxes['ax1'].set_xlabel('A big label')
someaxes['ax2'].set_xlabel('A big label')
someaxes['ax3'].set_xlabel('Label 2:2 Fast 2 Furious')


# overlap plots
x = np.array(['Luffy','Zoro','Nami','Usopp','Sanji'])
y1 = np.array([110,180,240,99,220])
y2 = np.array([110,100,90,120,50])

fig,ax = plt.subplots(figsize=(7,3))

ax.bar(x,y1,color ='indigo')
ax.plot(x,y2,color = 'red')

# overlap errorbar
y2_sd=np.std(y2)
fig,ax = plt.subplots(figsize=(7,3))
ax.plot(x,y2,color = 'red')
ax.errorbar(x,
            y2,
            yerr=y2_sd,
            fmt='none',
            ecolor='indigo',
            elinewidth = 4,
            capsize =6,
            capthick =4,
            errorevery = 2
            )

# import img
from PIL import Image
import requests
from io import BytesIO

url = "https://upload.wikimedia.org/wikipedia/en/c/cb/Monkey_D_Luffy.png"

headers = {
    "User-Agent": "Mozilla/5.0",
    "Accept": "image/*,*/*;q=0.8",
    "Referer": "https://en.wikipedia.org/"
}

response = requests.get(url, headers=headers)

image_file = BytesIO(response.content)
image = Image.open(image_file)

image

# add ax container for img; show img; save plts
fig,ax = plt.subplots(figsize=(7,3))

ax.plot(x,y2,color = 'red')
ax_image =fig.add_axes(
    [0.1,0.11,0.15,0.35]
)

ax_image.imshow(image)
ax_image.axis('off')

plt.savefig('plot1',dpi=300)

# %%
#############################################
# course 5: seaborn
#############################################
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests

# basic lineplot: aesthetic elements
tips=sns.load_dataset('tips')
print(tips)

plt.figure()
sns.set_style('whitegrid')
tipgraph = sns.lineplot(data =tips,
            x='total_bill',
            y='tip',
            color='hotpink',
            linestyle ='--',
            linewidth = 3,
            marker = 'o',
            markerfacecolor = 'indigo')


tipgraph.set(title ='TIPS VS TOATAL BILL',
            xlabel='Total Bill $',
            ylabel='Tip amount $')



# add multiple elements
plt.figure()
tipgraph1 = sns.scatterplot(data =tips,
            x='total_bill',
            y='tip',
            style ='time',
            hue='day',
            palette = ['purple','hotpink','deepskyblue','yellowgreen']
 )


tipgraph1.set(title ='TIPS VS TOATAL BILL',
            xlabel='Total Bill $',
            ylabel='Tip amount $')

# compare variables : pairplot and relplot
sns.pairplot (data =tips, hue='day')

daysplot=sns.relplot(data =tips,
            x='total_bill',
            y='tip',
            hue='sex',
            col='day',
            kind='scatter',
            col_wrap=2)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
##############################################
# course 5:
# interactive viz and quanlification
# plotly and wordcloud
##############################################
import plotly.graph_objects as go
from wordcloud import WordCloud
from matplotlib_venn import (
    venn2,
    venn2_circles,
    venn2_unweighted
)

x1 = np.array(["Luffy", "Zoro", "Nami", "Usopp", "Sanji"])
y1 = np.array([110, 180, 240, 99, 220])

graph =go.Figure()
graph.add_trace (go.Bar(x=x1,y=y1))
graph.update_layout(
    title="Pirate Scores",
    xaxis_title="Pirates",
    yaxis_title="Score"
)

graph.show()

#graph.write_html("pirategraph.html")
graph = go.Figure()

graph.add_trace(
    go.Scatter(
        x=x1,
        y=y1,
        mode='markers',
        marker=dict(
            size=15,
            color='hotpink',
            opacity=1,
            line=dict(width=5, color='purple')
        )
    )
)

graph.update_layout(
    title='Interactive Pirate Plot',
    xaxis_title='Pirates',
    yaxis_title='Scores',
    width=500,
    height=500
)

graph.show()

from wordcloud import WordCloud

df = pd.read_csv(
    "https://raw.githubusercontent.com/prasertcbs/basic-dataset/master/movie_quotes.csv",
    on_bad_lines='skip'
)
print (df)

# glue texts
text = "".join(each for each in df.quote)

wordcloud = WordCloud(
    background_color="white",
    colormap="inferno"
).generate(text)

fig, ax = plt.subplots(figsize=(7,3))

ax.imshow(wordcloud, interpolation='bilinear')
ax.axis("off")

A = set(["apple", "banana", "watermelon"])
B = set(["pumpkin", "blueberry", "apple", "key lime"])
diagram = venn2_unweighted(
    [A, B],
    set_labels=('Fruits', 'Pies'),
    set_colors=("blue", "red"),
    alpha=0.5
)



diagram.get_label_by_id("10").set_text("\n".join(A - B))

diagram.get_label_by_id("11").set_text("\n".join(A & B))

diagram.get_label_by_id("01").set_text("\n".join(B - A))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
