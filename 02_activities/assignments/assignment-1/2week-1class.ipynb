# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy
import PIL
import requests
np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0, 100,50)
y2 = np.random.randint(0, 100,50)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1)
ax.plot(x,y2)
fig.show()
# Out:
# /var/folders/fb/9qy5fcds6s17084zptz27q2w0000gn/T/ipykernel_15431/651223012.py:4: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1" )
ax.plot(x,y2, label = "Person 2" )
ax.legend(loc='lower right')
fig.show()
# Out:
# /var/folders/fb/9qy5fcds6s17084zptz27q2w0000gn/T/ipykernel_15431/133585955.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc='lower right'
,
frameon = True, #add frame around the legend
fontsize = 12, #change font size
ncol = 2, #specify number of columns
shadow = True )
fig.show()
# Out:
# /var/folders/fb/9qy5fcds6s17084zptz27q2w0000gn/T/ipykernel_15431/2598860340.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax.legend(loc=‘upper left’
,
bbox
to
_
_
anchor =(1, 1))
fig.show()
# Out:
#   Cell In[8], line 4
#     ax.legend(loc=‘upper left’
#                   ^
# SyntaxError: invalid character '‘' (U+2018)

# %%
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
ax. text(10,95, "This value is important!")
# Out:
# Text(10, 95, 'This value is important!')

# %%
ax.text(10, 95, "This value is important!", ##text to be displayed
        ha='center' , ##aligent of tex!"  
        color = 'red', ##modify font colour
        size = 20) ##modify font size


fig.show()
# Out:
# /var/folders/fb/9qy5fcds6s17084zptz27q2w0000gn/T/ipykernel_15431/4072310277.py:7: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots()
ax.axis([0, 10, 0, 10]) 

ax.text(1, 5, ". Data:(1, 5)", transform=ax.transData)
ax.text(0.5, 0.1, ". Axes:(0.5, 0.1)", transform=ax.transAxes)
ax.text(0.2, 0.2, ". Figure:(0.2, 0.2)", transform=fig.transFigure)
fig.show()
# Out:
# /var/folders/fb/9qy5fcds6s17084zptz27q2w0000gn/T/ipykernel_15431/3699091748.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5, 3))

ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")

ax.legend(loc='lower right')
ax.annotate('This is important!', xy=(10, 95), xytext=(20, 94),
            arrowprops=dict(arrowstyle = "wedge", color = "hotpink"),)

#ax.yaxis.set_major_locator(plt.NullLocator())
#ax.xaxis.set_major_formatter(plt.NullFormatter())
#ax.xaxis.set_major_locator(plt.MaxNLocator (3))

font1 = {' family':'serif'
,
'color':'indigo'}
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xlabel('Shiny New X Axis!'
, fontsize = 18, fontdict = font1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[32], line 21
#      19 ax.scatter(x,y2, label = "Person 2")
#      20 ax.legend(loc='lower right')
# ---> 21 plt.xlabel('Shiny New X Axis!'
#      22 , fontsize = 18, fontdict = font1)
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/pyplot.py:4359, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    4350 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    4351 def xlabel(
#    4352     xlabel: str,
#    (...)
#    4357     **kwargs,
#    4358 ) -> Text:
# -> 4359     return gca().set_xlabel(
#    4360         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4361     )
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/axes/_base.py:3556, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3549     x = {
#    3550         'left': 0,
#    3551         'center': 0.5,
#    3552         'right': 1,
#    3553     }[loc]
#    3554     kwargs.update(x=x, horizontalalignment=loc)
# -> 3556 return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/axis.py:1866, in Axis.set_label_text(self, label, fontdict, **kwargs)
#    1864 self.label.set_text(label)
#    1865 if fontdict is not None:
# -> 1866     self.label.update(fontdict)
#    1867 self.label.update(kwargs)
#    1868 self.stale = True
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/artist.py:1206, in Artist.update(self, props)
#    1198 def update(self, props):
#    1199     """
#    1200     Update this artist's properties from the dict *props*.
#    1201
#    (...)
#    1204     props : dict
#    1205     """
# -> 1206     return self._update_props(
#    1207         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/artist.py:1190, in Artist._update_props(self, props, errfmt)
#    1188             func = getattr(self, f"set_{k}", None)
#    1189             if not callable(func):
# -> 1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
#    1192             ret.append(func(v))
#    1193 if ret:
#
# AttributeError: 'Text' object has no property ' family'

# %%
font1 = {' family':'serif'
,
'color':'indigo'}
fig, ax = plt.subplots(figsize=(5, 3))
ax.scatter(x,y1, label = "Person 1")
ax.scatter(x,y2, label = "Person 2")
ax.legend(loc='lower right')
plt.xlabel('Shiny New X Axis!'
, fontsize = 18, fontdict = font1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 8
#       6 ax.scatter(x,y2, label = "Person 2")
#       7 ax.legend(loc='lower right')
# ----> 8 plt.xlabel('Shiny New X Axis!'
#       9 , fontsize = 18, fontdict = font1)
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/pyplot.py:4359, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    4350 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    4351 def xlabel(
#    4352     xlabel: str,
#    (...)
#    4357     **kwargs,
#    4358 ) -> Text:
# -> 4359     return gca().set_xlabel(
#    4360         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4361     )
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/axes/_base.py:3556, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3549     x = {
#    3550         'left': 0,
#    3551         'center': 0.5,
#    3552         'right': 1,
#    3553     }[loc]
#    3554     kwargs.update(x=x, horizontalalignment=loc)
# -> 3556 return self.xaxis.set_label_text(xlabel, fontdict, **kwargs)
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/axis.py:1866, in Axis.set_label_text(self, label, fontdict, **kwargs)
#    1864 self.label.set_text(label)
#    1865 if fontdict is not None:
# -> 1866     self.label.update(fontdict)
#    1867 self.label.update(kwargs)
#    1868 self.stale = True
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/text.py:205, in Text.update(self, kwargs)
#     203 # Update bbox last, as it depends on font properties.
#     204 bbox = kwargs.pop("bbox", sentinel)
# --> 205 ret.extend(super().update(kwargs))
#     206 if bbox is not sentinel:
#     207     ret.append(self.set_bbox(bbox))
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/artist.py:1206, in Artist.update(self, props)
#    1198 def update(self, props):
#    1199     """
#    1200     Update this artist's properties from the dict *props*.
#    1201
#    (...)
#    1204     props : dict
#    1205     """
# -> 1206     return self._update_props(
#    1207         props, "{cls.__name__!r} object has no property {prop_name!r}")
#
# File ~/miniconda3/envs/dsi_participant/lib/python3.9/site-packages/matplotlib/artist.py:1190, in Artist._update_props(self, props, errfmt)
#    1188             func = getattr(self, f"set_{k}", None)
#    1189             if not callable(func):
# -> 1190                 raise AttributeError(
#    1191                     errfmt.format(cls=type(self), prop_name=k))
#    1192             ret.append(func(v))
#    1193 if ret:
#
# AttributeError: 'Text' object has no property ' family'

# %%
##plot both y variables on the same axis
[9]
ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1, label = "Person 1")
ax.plot(x,y2, label = "Person 2")
ax. legend(loc = 'lower right',
frameon
= True,
fontsize
= 12,
ncol = 2,
shadow = Truel
# Out:
#   Cell In[2], line 12
#     shadow = Truel
#                   ^
# SyntaxError: unexpected EOF while parsing

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y1,label = "Person 1")
ax.plot(x,y2,label = "Person 2")
ax. legend(loc = 'upper left',
bbox_to_anchor = (1,1)D
# Out:
#   Cell In[3], line 5
#     bbox_to_anchor = (1,1)D
#                           ^
# SyntaxError: invalid syntax
