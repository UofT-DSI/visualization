# %% [markdown]
# Lecture 2 activity notes. Reviewing different types of visualizations.
#
# -Visualization #1: From this visualization, we can learn by what age people were killed by gun violenece and how many years were stolen from them as a result. We can also learn how each of them was killed by clicking on individual line as the visualization is interactive. But this visualization is not neutral or objective as they use strong words like "years stolen" when we don't even know how long each of those poeple would live. It also provides a reason for killings to influence on people's emotions even more.
#
# -Visualization #2: From this visualization, we can learn how many active shooters there were in each year. This visualization is more neutral than the previous one but it's unclear what they mean by "active shooters". Some people may interpret "active shooters" differently, which is dishonest. Also, we don't know which state or city this visualization represents.
