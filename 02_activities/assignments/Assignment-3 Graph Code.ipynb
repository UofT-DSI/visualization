# %%
#Loading Libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
import PIL as pil
import requests

# %%
	
# Toronto Open Data is stored in a CKAN instance. It's APIs are documented here:
# https://docs.ckan.org/en/latest/api/
 
# To hit our API, you'll be making requests to:
base_url = "https://ckan0.cf.opendata.inter.prod-toronto.ca"
 
# Datasets are called "packages". Each package can contain many "resources"
# To retrieve the metadata for this package and its resources, use the package name in this page's URL:
url = base_url + "/api/3/action/package_show"
params = { "id": "dogs-issued-dangerous-dog-orders"}
package = requests.get(url, params = params).json()
 

# To get resource data:
for idx, resource in enumerate(package["result"]["resources"]):
 
       # for datastore_active resources:
       if resource["datastore_active"]:
 
           # To get all records in CSV format:
           url = base_url + "/datastore/dump/" + resource["id"]
           resource_dump_data = requests.get(url).text
           print(resource_dump_data)
 
           # To selectively pull records and attribute-level metadata:
           url = base_url + "/api/3/action/datastore_search"
           p = { "id": resource["id"] }
           resource_search_data = requests.get(url, params = p).json()["result"]
           print(resource_search_data)
           # This API call has many parameters. They're documented here:
           # https://docs.ckan.org/en/latest/maintaining/datastore.html
 
       # To get metadata for non datastore_active resources:
       if not resource["datastore_active"]:
           url = base_url + "/api/3/action/resource_show?id=" + resource["id"]
           resource_metadata = requests.get(url).json()
           print(resource_metadata)
           # From here, you can use the "url" attribute to download this file
# Out:
# _id,Forward_Sortation_Area,Name_of_Dog,Breed,Color,Ward_Number,Ward_Name,Bite_Circumstance,Location_of_Incident,Date_of_Dangerous_Act
# 1,M6R,CHLOE,BEAGLE MIX,TAN / WHITE,04,Parkdale-High Park,VERY SEVERE,PUBLIC PROPERTY,2017-03-09
# 2,M3M,OSO,AKITA,WHITE / BLACK,06,York Centre,SEVERE,PARK - LEASH REQUIRED AREA,2017-03-11
# 3,M4N,HOBBES,CANE CORSO / LABRADOR RETR,BR BRINDLE,15,Don Valley West,SEVERE,OWNERS PROPERTY,2017-03-18
# 4,M9W,HUNTER,GOLDEN RETR,GOLD,01,Etobicoke North,SEVERE,OTHER PRIVATE PROPERTY,2017-03-23
# 5,M1E,LILA,GERM SHEPHERD / AUST SHEPHERD,BLACK / TAN,25,Scarborough-Rouge Park,NON SEVERE,PARK - LEASH FREE AREA,2017-03-29
# 6,M3H,BRODY,ALASKAN HUSKY MIX,GREY / WHITE,06,York Centre,NON SEVERE,PARK - LEASH FREE AREA,2017-04-16
# 7,M6R,TANGO,AUST SHEPHERD,RED MERLE,04,Parkdale-High Park,NON SEVERE,PUBLIC PROPERTY,2017-04-19
# 8,M1B,LEO,ROTTWEILER / BORDER COLLIE,BLACK / BROWN,23,Scarborough North,NON SEVERE,PARK - LEASH REQUIRED AREA,2017-04-26
# 9,M2R,DASUL,JINDO,WHITE,18,Willowdale,NON SEVERE,OTHER PRIVATE PROPERTY,2017-06-21
# 10,M4B,BRANDY,AM PIT BULL TER,WHITE / TAN,19,Beaches-East York,SEVERE,OTHER PRIVATE PROPERTY,2017-06-24
# 11,M1W,TIGER,BOXER / AMER BULLDOG,BROWN / WHITE,22,Scarborough-Agincourt,SEVERE,PARK - LEASH REQUIRED AREA,2017-06-25
# 12,M4K,NEMO,SIBERIAN HUSKY,WHITE / GREY,14,Toronto-Danforth,SEVERE,PUBLIC PROPERTY,2017-08-02
# 13,M9A,ROCKY,GERM SHEPHERD MIX,BLACK / TAN,02,Etobicoke Centre,NON SEVERE,OWNERS PROPERTY,2017-09-29
# 14,M4J,MAX,GERM SHEPHERD,SABLE,14,Toronto-Danforth,NON SEVERE,PARK - LEASH FREE AREA,2017-10-02
# 15,M6N,MYA,ROTTWEILER,BLACK / TAN,05,York South-Weston,SEVERE,PUBLIC PROPERTY,2017-10-24
# 16,M2N,ROSEY,ROTTWEILER,BLACK / TAN,18,Willowdale,SEVERE,OWNERS PROPERTY,2017-11-04
# 17,No FSA Info,DANNY,BELG MALINOIS MIX,BROWN / BLACK,,No Ward Info,NON SEVERE,OTHER PRIVATE PROPERTY,2018-02-11
# 18,M6N,CHINA,LABRADOR RETR / CHINESE SHARPEI,TAN / WHITE,09,Davenport,SEVERE,PARK - LEASH FREE AREA,2018-02-11
# 19,M4S,RONIN,ROTTWEILER,BLACK / TAN,12,Toronto-St. Paul's,NON SEVERE,OTHER PRIVATE PROPERTY,2018-02-25
# 20,M6M,DUCHESS,ROTTWEILER / STAFFORDSHIRE,BROWN / BLACK,05,York South-Weston,SEVERE,OTHER PRIVATE PROPERTY,2018-03-24
# 21,M1G,MOOKI,AKBASH / GERM SHEPHERD,TAN,24,Scarborough-Guildwood,SEVERE,OTHER PRIVATE PROPERTY,2018-04-08
# 22,M1M,MAVIS,LABRADOR RETR / BORDER COLLIE,TRICOLOUR,20,Scarborough Southwest,SEVERE,PARK - LEASH FREE AREA,2018-04-18
# 23,M4C,TITAN,LABRADOR RETR / AMER BULLDOG,CHOCOLATE / WHITE,19,Beaches-East York,SEVERE,PARK - LEASH REQUIRED AREA,2018-04-21
# 24,M8Y,GEORGE,GOLDEN RETR / POODLE STND,CREAM / WHITE,03,Etobicoke-Lakeshore,SEVERE,PUBLIC PROPERTY,2018-05-23
# 25,M6M,ROCKY,BICHON FRISE / POODLE MIN,WHITE,05,York South-Weston,NON SEVERE,OWNERS PROPERTY,2018-05-24
# 26,M1E,ROMULUS,RHOD RIDGEBACK / GERM SHEPHERD,TAN,24,Scarborough-Guildwood,VERY SEVERE,OTHER PRIVATE PROPERTY,2018-06-02
# 27,M6A,BEAU,LABRADOR RETR,BLACK,08,Eglinton-Lawrence,VERY SEVERE,OTHER PRIVATE PROPERTY,2018-07-09
# 28,M6E,THEODORE,PUG / BOSTON TERRIER,BLACK / WHITE,09,Davenport,NON SEVERE,OWNERS PROPERTY,2018-07-23
# 29,M1W,SADIE,BOXER / GERM SHEPHERD,TAN,22,Scarborough-Agincourt,SEVERE,PUBLIC PROPERTY,2018-08-03
# 30,M1W,TORY,SHIH TZU,WHITE / GREY,22,Scarborough-Agincourt,NON SEVERE,OTHER PRIVATE PROPERTY,2018-08-14
# 31,M6A,PRINCE,LABRADOR RETR,BLACK,08,Eglinton-Lawrence,NON SEVERE,OWNERS PROPERTY,2018-08-15
# 32,M4B,TITAN,GERM SHEPHERD,BLACK / TAN,19,Beaches-East York,SEVERE,OTHER PRIVATE PROPERTY,2018-08-31
# 33,M2J,JAXSON,SIBERIAN HUSKY / GERM SHEPHERD,TAN / BLACK,17,Don Valley North,NAB,OTHER PRIVATE PROPERTY,2018-09-17
# 34,M4K,AIDEN,SC WHEAT TERR,WHITE,14,Toronto-Danforth,NON SEVERE,PUBLIC PROPERTY,2018-09-23
# 35,M8Y,DUTCH,MASTIFF / CANE CORSO,GREY / WHITE,03,Etobicoke-Lakeshore,SEVERE,PUBLIC PROPERTY,2018-10-29
# 36,M6M,TROUBLE,LABRADOR RETR,BLACK,05,York South-Weston,SEVERE,PUBLIC PROPERTY,2018-11-02
# 37,M9N,PONGO,MIN PINSCHER MIX,BLACK / TAN,05,York South-Weston,SEVERE,PUBLIC PROPERTY,2018-11-04
# 38,M4Y,ILA,BOXER / BULL TERRIER,FAWN,13,Toronto Centre,SEVERE,OTHER PRIVATE PROPERTY,2018-11-25
# 39,M9W,HUNTER,GERM SHEPHERD,BROWN / BLACK,01,Etobicoke North,SEVERE,PUBLIC PROPERTY,2019-01-18
# 40,M4K,BRUNO,ROTTWEILER / GERM SHEPHERD,BLACK / TAN,14,Toronto-Danforth,SEVERE,OWNERS PROPERTY,2019-01-29
# 41,M4J,ELIE,GERM SHEPHERD,BROWN / BLACK,14,Toronto-Danforth,SEVERE,OWNERS PROPERTY,2019-02-10
# 42,M3A,BELLA,AMER BULLDOG MIX,BROWN,16,Don Valley East,VERY SEVERE,OTHER PRIVATE PROPERTY,2019-03-31
# 43,M8Y,TONY,AMER BULLDOG,WHITE / BLACK,03,Etobicoke-Lakeshore,SEVERE,PUBLIC PROPERTY,2019-04-01
# 44,M8V,BARKLEY,BORDER COLLIE / GOLDEN RETR,BLACK / WHITE,03,Etobicoke-Lakeshore,SEVERE,PUBLIC PROPERTY,2019-04-22
# 45,M9P,MILO,YORKSHIRE TERR / POODLE MIN,GOLD,01,Etobicoke North,NON SEVERE,OTHER PRIVATE PROPERTY,2019-04-24
# 46,M6H,MR. BROWN,BOXER / LABRADOR RETR,BROWN / WHITE,09,Davenport,NON SEVERE,PUBLIC PROPERTY,2019-05-08
# 47,M4M,BELLA,AUST CATTLE DOG / LABRADOR RETR,GREY / BLACK,14,Toronto-Danforth,SEVERE,OTHER PRIVATE PROPERTY,2019-05-14
# 48,M2H,RONIN,GERM SHEPHERD,BLACK / RED,17,Don Valley North,NON SEVERE,PUBLIC PROPERTY,2019-05-18
# 49,M1B,SCOOBY,MASTIFF MIX,BROWN / WHITE,25,Scarborough-Rouge Park,SEVERE,OTHER PRIVATE PROPERTY,2019-06-07
# 50,M4Y,BO,GERM SHEPHERD,BEIGE / BLACK,13,Toronto Centre,SEVERE,PUBLIC PROPERTY,2019-06-11
# 51,M1H,ODIE,PARSON RUSS TER,WHITE / BROWN,24,Scarborough-Guildwood,NON SEVERE,OWNERS PROPERTY,2019-06-15
# 52,M3L,REX,GERM SHEPHERD MIX,BLACK / TAN,06,York Centre,SEVERE,PUBLIC PROPERTY,2019-06-18
# 53,M1B,CHARLI THASA,GERM SHEPHERD / LABRADOR RETR,BROWN / BLACK,25,Scarborough-Rouge Park,SEVERE,OTHER PRIVATE PROPERTY,2019-06-22
# 54,M6K,TUCKER,ENG COONHOUND,RED,04,Parkdale-High Park,SEVERE,OWNERS PROPERTY,2019-06-27
# 55,M5B,CLYDE,AMER BULLDOG / MASTIFF,BR BRINDLE / WHITE,13,Toronto Centre,NON SEVERE,OTHER PRIVATE PROPERTY,2019-07-01
# 56,M4A,CHARLIE,GERM SHEPHERD,BLACK / TAN,19,Beaches-East York,NON SEVERE,PUBLIC PROPERTY,2019-07-17
# 57,M1M,CHESTER,BULLMASTIFF,BROWN,20,Scarborough Southwest,SEVERE,OWNERS PROPERTY,2019-07-18
# 58,M1E,ZION,MASTIFF,BROWN,25,Scarborough-Rouge Park,VERY SEVERE,OTHER PRIVATE PROPERTY,2019-08-03
# 59,M1E,SHATTER,SIBERIAN HUSKY,BLACK / WHITE,25,Scarborough-Rouge Park,VERY SEVERE,OTHER PRIVATE PROPERTY,2019-08-03
# 60,M3B,JOSIE,COCKER SPAN,BLACK,15,Don Valley West,VERY SEVERE,PUBLIC PROPERTY,2019-09-23
# 61,M1S,ZHAZHA,GERM SHEPHERD,BLACK / YELLOW,23,Scarborough North,NOT A BITE,OWNERS PROPERTY,2019-10-10
# 62,M3C,MYSTIC,AMER BULLDOG / BULLMASTIFF,CHOCOLATE,16,Don Valley East,SEVERE,OTHER PRIVATE PROPERTY,2019-10-22
# 63,M1J,DIESEL,ROTTWEILER / BOXER,BROWN / WHITE,20,Scarborough Southwest,VERY SEVERE,OWNERS PROPERTY,2019-11-22
# 64,M2R,BAMBI,AMER BULLDOG,WHITE / BR BRINDLE,18,Willowdale,SEVERE,PUBLIC PROPERTY,2019-11-27
# 65,M1K,AURORA,BORDER COLLIE MIX,WHITE / BLACK,21,Scarborough Centre,NON SEVERE,OTHER PRIVATE PROPERTY,2020-02-06
# 66,M2M,BEAR,GERM SHEPHERD MIX,BLACK / TAN,18,Willowdale,SEVERE,PUBLIC PROPERTY,2020-02-21
# 67,M1E,DESIL,CANE CORSO / ROTTWEILER,BR BRINDLE,24,Scarborough-Guildwood,SEVERE,OTHER PRIVATE PROPERTY,2020-03-04
# 68,M1M,JAX,AMER BULLDOG,WHITE / BROWN,20,Scarborough Southwest,NON SEVERE,PUBLIC PROPERTY,2020-04-05
# 69,M1W,KING,DOGO ARGENTINO,WHITE,22,Scarborough-Agincourt,SEVERE,PUBLIC PROPERTY,2020-05-03
# 70,M8V,XENA,LABRADOR RETR / GERM SHEPHERD,BEIGE,03,Etobicoke-Lakeshore,SEVERE,PARK - LEASH REQUIRED AREA,2020-06-09
# 71,M1P,NEVAH,BOXER,TAN,21,Scarborough Centre,SEVERE,PUBLIC PROPERTY,2020-06-11
# 72,M5P,CECIL,FRENCH BULLDOG,BLACK,12,Toronto-St. Paul's,SEVERE,PARK - LEASH REQUIRED AREA,2020-06-14
# 73,M1T,HENNY,LABRADOR RETR / AMER BULLDOG,BROWN / TAN,22,Scarborough-Agincourt,NON SEVERE,OTHER PRIVATE PROPERTY,2020-06-20
# 74,M4C,DEXTOR,BELG MALINOIS,BROWN,19,Beaches-East York,NON SEVERE,OWNERS PROPERTY,2020-07-23
# 75,M4Y,PICASSO,COTON DE TULEAR,WHITE,11,University-Rosedale,NON SEVERE,OTHER PRIVATE PROPERTY,2020-07-28
# 76,M6M,CRONUS,MASTIFF / CANE CORSO,SABLE / BROWN,05,York South-Weston,SEVERE,OWNERS PROPERTY,2020-08-01
# 77,M6K,ZIGGY,HOUND,BLACK / BROWN,04,Parkdale-High Park,SEVERE,OTHER PRIVATE PROPERTY,2020-08-14
# 78,M2J,LUNA,SIBERIAN HUSKY,WHITE / BLACK,17,Don Valley North,SEVERE,PUBLIC PROPERTY,2020-08-31
# 79,M2J,ROCCO,ALASKAN HUSKY,RED / WHITE,17,Don Valley North,SEVERE,PUBLIC PROPERTY,2020-08-31
# 80,M4K,RABBIT,LABRADOR RETR / AMER BULLDOG,WHITE / TAN,14,Toronto-Danforth,SEVERE,PUBLIC PROPERTY,2020-09-03
# 81,M1K,MEEKA,AKITA,TAN / WHITE,21,Scarborough Centre,SEVERE,PUBLIC PROPERTY,2020-09-08
# 82,M4C,COCO,AMER BULLDOG,WHITE / BROWN,19,Beaches-East York,SEVERE,PARK - LEASH REQUIRED AREA,2020-09-13
# 83,M4J,ROCKY,BELG MALINOIS,BROWN,14,Toronto-Danforth,NON SEVERE,PUBLIC PROPERTY,2020-09-21
# 84,M4V,NETWORK,GERM SHEPHERD,BLACK / TAN,12,Toronto-St. Paul's,NON SEVERE,OWNERS PROPERTY,2020-09-23
# 85,M5A,BODHI,AMER BULLDOG MIX,BROWN / WHITE,13,Toronto Centre,SEVERE,PARK - LEASH FREE AREA,2020-10-20
# 86,M4E,SERA,GERM SHEPHERD / AMER BULLDOG,BR BRINDLE / WHITE,19,Beaches-East York,SEVERE,PUBLIC PROPERTY,2020-11-10
# 87,M1K,ZEUS,MASTIFF / DOGO ARGENTINO,BL BRINDLE / WHITE,20,Scarborough Southwest,SEVERE,OTHER PRIVATE PROPERTY,2020-11-15
# 88,M2J,MAJOR,AMER BULLDOG / ROTTWEILER,TAN,17,Don Valley North,NON SEVERE,PUBLIC PROPERTY,2020-12-19
# 89,M1V,LION,GERM SHEPHERD,BLACK / TAN,22,Scarborough-Agincourt,NON SEVERE,PUBLIC PROPERTY,2021-01-24
# 90,M9R,SASHA,AKITA,WHITE / TAN,01,Etobicoke North,SEVERE,PARK - LEASH REQUIRED AREA,2021-01-26
# 91,M3H,DASH,GERM SHEPHERD MIX,BLACK / BROWN,06,York Centre,NON SEVERE,PUBLIC PROPERTY,2021-02-21
# 92,M5N,STORM,NS DUCK TOLLING,RED,08,Eglinton-Lawrence,NON SEVERE,OWNERS PROPERTY,2021-02-25
# 93,M9A,ZEUS,AMER BULLDOG MIX,BLACK / WHITE,02,Etobicoke Centre,NON SEVERE,OTHER PRIVATE PROPERTY,2021-03-05
# 94,M9B,KAI,MASTIFF,RED,02,Etobicoke Centre,NON SEVERE,OTHER PRIVATE PROPERTY,2021-03-18
# 95,M4J,XENA,AMER BULLDOG,BLACK,14,Toronto-Danforth,SEVERE,OTHER PRIVATE PROPERTY,2021-04-08
# 96,M4J,LULU,AMER BULLDOG,BROWN / WHITE,14,Toronto-Danforth,SEVERE,PUBLIC PROPERTY,2021-05-04
# 97,M6N,HABIBA,DOGO ARGENTINO,WHITE,05,York South-Weston,NON SEVERE,OTHER PRIVATE PROPERTY,2021-05-09
# 98,M6N,ZATAR,DOGO ARGENTINO,WHITE,05,York South-Weston,NON SEVERE,OTHER PRIVATE PROPERTY,2021-05-09
# 99,M3A,PEPPER,BOXER,BR BRINDLE / WHITE,16,Don Valley East,NOT A BITE,PUBLIC PROPERTY,2021-05-11
# 100,M6A,GREYDEE,COCKER SPAN,BLUE TICK,08,Eglinton-Lawrence,NOT A BITE,OTHER PRIVATE PROPERTY,2021-05-17
# 101,M3C,KUSH,BULLDOG MIX,BLACK / WHITE,16,Don Valley East,NON SEVERE,OWNERS PROPERTY,2021-06-02
# 102,M1M,REX,GERM SHEPHERD,BLACK / TAN,20,Scarborough Southwest,SEVERE,OTHER PRIVATE PROPERTY,2021-06-09
# 103,M1R,LOVE,GREAT DANE,BROWN / WHITE,21,Scarborough Centre,NON SEVERE,OTHER PRIVATE PROPERTY,2021-06-19
# 104,M5R,BRADY,CANE CORSO,ORANGE / BL BRINDLE,11,University-Rosedale,SEVERE,OTHER PRIVATE PROPERTY,2021-06-21
# 105,M3B,SHADOW,GERM SHEPHERD,BLACK / YELLOW,16,Don Valley East,NON SEVERE,PUBLIC PROPERTY,2021-06-27
# 106,M1L,ROMEO,BULL TERRIER,BLACK / WHITE,20,Scarborough Southwest,SEVERE,PUBLIC PROPERTY,2021-08-04
# 107,M1V,BLUE,CHOW CHOW,RED,23,Scarborough North,SEVERE,PUBLIC PROPERTY,2021-08-31
# 108,M1V,TEDDY,CHOW CHOW,RED,23,Scarborough North,SEVERE,PUBLIC PROPERTY,2021-08-31
# 109,M4J,KLONDIKE,GREYHOUND,BUFF,14,Toronto-Danforth,SEVERE,OWNERS PROPERTY,2021-09-18
# 110,M3K,KHAN,BOXER / MASTIFF,BR BRINDLE,06,York Centre,NON SEVERE,PARK - LEASH REQUIRED AREA,2021-09-20
# 111,M6H,MYLES,AMERICAN STAFF / AMER BULLDOG,YELLOW,09,Davenport,SEVERE,OTHER PRIVATE PROPERTY,2021-09-24
# 112,M9C,MAGNUS,ROTTWEILER / GERM SHEPHERD,BLACK / TAN,02,Etobicoke Centre,NOT A BITE,OTHER PRIVATE PROPERTY,2021-10-06
# 113,M1B,PRINCE,BOXER,BROWN,23,Scarborough North,SEVERE,PUBLIC PROPERTY,2021-10-07
# 114,M1N,ZEUS,BULLMASTIFF MIX,BR BRINDLE,20,Scarborough Southwest,NON SEVERE,PUBLIC PROPERTY,2021-10-07
# 115,M6G,RUSTY,BORDER COLLIE / MASTIFF,BLACK / WHITE,11,University-Rosedale,SEVERE,OTHER PRIVATE PROPERTY,2021-10-11
# 116,M4E,SHEWY,DOGO ARGENTINO,WHITE,19,Beaches-East York,SEVERE,OTHER PRIVATE PROPERTY,2021-10-27
# 117,M9A,RYE,CHOW CHOW / LABRADOR RETR,YELLOW,02,Etobicoke Centre,NON SEVERE,PUBLIC PROPERTY,2021-11-13
# 118,M4Y,STALLION,AKITA,CREAM / WHITE,11,University-Rosedale,SEVERE,OTHER PRIVATE PROPERTY,2021-12-02
# 119,M1S,ZEUS,DOGO ARGENTINO,WHITE,22,Scarborough-Agincourt,SEVERE,OTHER PRIVATE PROPERTY,2022-01-12
# 120,M2N,JOEY,GERM SHEPHERD,TAN / BLACK,18,Willowdale,NON SEVERE,PUBLIC PROPERTY,2022-01-13
# 121,M4L,MAYA,LABRADOR RETR / BOSTON TERRIER,BLACK / WHITE,14,Toronto-Danforth,SEVERE,PARK - LEASH REQUIRED AREA,2022-01-19
# 122,M4A,GRIFFIN,ROTTWEILER / LABRADOR RETR,BR BRINDLE / BLACK,16,Don Valley East,NON SEVERE,PARK - LEASH FREE AREA,2022-01-26
# 123,M9R,VENOM,BELG MALINOIS,BROWN / BLACK,02,Etobicoke Centre,SEVERE,OTHER PRIVATE PROPERTY,2022-02-02
# 124,M1K,REMY,AMER BULLDOG,WHITE / BR BRINDLE,21,Scarborough Centre,SEVERE,PARK - LEASH REQUIRED AREA,2022-02-05
# 125,M9M,BONES,BORDER COLLIE / LABRADOR RETR,BLACK / WHITE,07,Humber River-Black Creek,NON SEVERE,PUBLIC PROPERTY,2022-02-10
# 126,M4C,HUNDO,GERM SHEPHERD / LABRADOR RETR,BLACK / BROWN,19,Beaches-East York,NOT A BITE,OTHER PRIVATE PROPERTY,2022-02-20
# 127,M5J,TATSU,AKITA,WHITE / BLACK,10,Spadina-Fort York,NON SEVERE,PUBLIC PROPERTY,2022-03-15
# 128,M3J,MILO,AMER BULLDOG,BR BRINDLE / WHITE,07,Humber River-Black Creek,NON SEVERE,PUBLIC PROPERTY,2022-03-18
# 129,M2K,SHADOW,AUST SHEPHERD,TRICOLOUR / BLACK,18,Willowdale,SEVERE,PUBLIC PROPERTY,2022-03-20
# 130,M5S,ODIN,SIBERIAN HUSKY,GREY / WHITE,11,University-Rosedale,NON SEVERE,PUBLIC PROPERTY,2022-04-23
# 131,M4Y,BROCCOLI,CAROLINA DOG MIX,TAN,13,Toronto Centre,SEVERE,OTHER PRIVATE PROPERTY,2022-04-25
# 132,M4J,KING,ROTTWEILER,BLACK / BROWN,14,Toronto-Danforth,SEVERE,PARK - LEASH FREE AREA,2022-05-11
# 133,M6R,MAIA,ROTTWEILER / LABRADOR RETR,BLACK / TAN,04,Parkdale-High Park,SEVERE,PUBLIC PROPERTY,2022-05-14
# 134,M2J,PABLO,OLD ENG BULLDOG,BLUE,17,Don Valley North,SEVERE,OTHER PRIVATE PROPERTY,2022-05-17
# 135,M4V,BEATRIX,WEIMARANER,GREY,12,Toronto-St. Paul's,SEVERE,PUBLIC PROPERTY,2022-05-20
# 136,M5R,MOOSE,BOSTON TERRIER,BROWN / WHITE,12,Toronto-St. Paul's,SEVERE,PUBLIC PROPERTY,2022-05-27
# 137,M4J,SHYLA,AMER BULLDOG MIX,BROWN,14,Toronto-Danforth,SEVERE,OTHER PRIVATE PROPERTY,2022-06-09
# 138,M9N,REINA,AMER BULLDOG MIX,GREY,05,York South-Weston,SEVERE,OWNERS PROPERTY,2022-06-12
# 139,M9N,PATRON,CANE CORSO MIX,GREY,05,York South-Weston,SEVERE,OWNERS PROPERTY,2022-06-12
# 140,M6K,KEIKO,WHIPPET / VIZSLA,BROWN,10,Spadina-Fort York,SEVERE,PUBLIC PROPERTY,2022-06-14
# 141,M1L,MOLLY,LABRADOR RETR,YELLOW,20,Scarborough Southwest,SEVERE,PUBLIC PROPERTY,2022-06-15
# 142,M4P,KATO,CHOW CHOW / SIBERIAN HUSKY,TAN,15,Don Valley West,NOT A BITE,OTHER PRIVATE PROPERTY,2022-06-22
# 143,M1N,MAKEUP,BULLMASTIFF / AM PIT BULL TER,BROWN / WHITE,20,Scarborough Southwest,NON SEVERE,PARK - LEASH FREE AREA,2022-06-24
# 144,M1C,ANUBIS,SIBERIAN HUSKY / AKITA,GREY / BLACK,25,Scarborough-Rouge Park,SEVERE,PARK - LEASH REQUIRED AREA,2022-06-30
# 145,M4G,CASSIE,GOLDEN RETR,GOLD,15,Don Valley West,SEVERE,PARK - LEASH REQUIRED AREA,2022-07-02
# 146,M6B,DIGGY,ROTTWEILER / MASTIFF,RED,08,Eglinton-Lawrence,SEVERE,PUBLIC PROPERTY,2022-07-03
# 147,M4L,LUNA,ROTTWEILER,BLACK / TAN,14,Toronto-Danforth,NON SEVERE,PUBLIC PROPERTY,2022-07-09
# 148,M2M,BLUE,BULLMASTIFF,BROWN,18,Willowdale,SEVERE,OWNERS PROPERTY,2022-07-09
# 149,M5R,CAROL,SIBERIAN HUSKY,BLACK / WHITE,12,Toronto-St. Paul's,SEVERE,PUBLIC PROPERTY,2022-07-14
# 150,M4M,FIN,GERM SHEPHERD,BLACK,14,Toronto-Danforth,SEVERE,OWNERS PROPERTY,2022-07-14
# 151,M4L,BELLA,SHIH TZU,BLACK,14,Toronto-Danforth,NON SEVERE,OTHER PRIVATE PROPERTY,2022-07-20
# 152,M4B,REMY,ROTTWEILER,BLACK / TAN,19,Beaches-East York,SEVERE,OTHER PRIVATE PROPERTY,2022-07-20
# 153,M6C,KAIBO,PORT WATER DOG,BLACK / WHITE,12,Toronto-St. Paul's,NON SEVERE,OTHER PRIVATE PROPERTY,2022-07-26
# 154,M2J,SKY,BORDER COLLIE / LABRADOR RETR,RED / WHITE,17,Don Valley North,NON SEVERE,PUBLIC PROPERTY,2022-07-26
# 155,M4X,ROLO,ENG BULLDOG / BOXER,TAN / WHITE,13,Toronto Centre,NON SEVERE,OTHER PRIVATE PROPERTY,2022-07-28
# 156,M4L,KEELOW,BULLMASTIFF,BR BRINDLE / WHITE,14,Toronto-Danforth,SEVERE,PUBLIC PROPERTY,2022-07-28
# 157,M3J,TACO,SIBERIAN HUSKY,BROWN / WHITE,06,York Centre,SEVERE,PUBLIC PROPERTY,2022-07-31
# 158,M2P,CHARLOTTE,GERM SHEPHERD MIX,BLACK,15,Don Valley West,NON SEVERE,PUBLIC PROPERTY,2022-08-04
# 159,M1B,MERCY,MASTIFF MIX,BLACK / BROWN,25,Scarborough-Rouge Park,SEVERE,PUBLIC PROPERTY,2022-08-12
# 160,L9C,BRUNA,RUSSIAN TERRIER,BLACK,04,Parkdale-High Park,NON SEVERE,OTHER PRIVATE PROPERTY,2022-08-15
# 161,M4X,PEACHES,AM PIT BULL TER / LABRADOR RETR,TAN / WHITE,13,Toronto Centre,SEVERE,PARK - LEASH FREE AREA,2022-08-22
# 162,M4X,BLUE,AMER BULLDOG / BOXER,GREY / WHITE,13,Toronto Centre,SEVERE,PARK - LEASH FREE AREA,2022-08-22
# 163,M1S,BENTLEY,OLDENG SHEEPDOG / POODLE STND,BLACK / WHITE,22,Scarborough-Agincourt,SEVERE,OTHER PRIVATE PROPERTY,2022-08-28
# 164,M1V,SATCHEL,SC WHEAT TERR,CREAM,23,Scarborough North,SEVERE,OTHER PRIVATE PROPERTY,2022-08-28
# 165,M1G,SABER,BORDER COLLIE / AUST CATTLE DOG,BLACK / WHITE,24,Scarborough-Guildwood,SEVERE,OWNERS PROPERTY,2022-08-29
# 166,M4M,FELIX,GERM SHEPHERD MIX,BLACK / TAN,14,Toronto-Danforth,SEVERE,PUBLIC PROPERTY,2022-09-04
# 167,M4M,SAM,SIBERIAN HUSKY MIX,WHITE / BLACK,14,Toronto-Danforth,SEVERE,PUBLIC PROPERTY,2022-09-04
# 168,M5V,STANLEY,ROTTWEILER / LABRADOR RETR,BROWN / BLACK,10,Spadina-Fort York,NON SEVERE,PARK - LEASH FREE AREA,2022-09-06
# 169,M3B,PEANUT,GOLDEN RETR / BASSET HOUND,TAN,16,Don Valley East,SEVERE,PUBLIC PROPERTY,2022-09-17
# 170,M4M,ESME,OLD ENG BULLDOG,WHITE / BLACK,14,Toronto-Danforth,SEVERE,PUBLIC PROPERTY,2022-09-17
# 171,M6S,ROMAN,BULLMASTIFF / PRESA CANARIO,FAWN,04,Parkdale-High Park,NON SEVERE,PUBLIC PROPERTY,2022-09-26
# 172,M4H,MAYA,AM PIT BULL TER / ENG BULLDOG,TAN / WHITE,15,Don Valley West,NON SEVERE,OTHER PRIVATE PROPERTY,2022-10-01
# 173,M6M,FRANKLIN,POODLE STND,BR BRINDLE,05,York South-Weston,SEVERE,PUBLIC PROPERTY,2022-10-05
# 174,M3N,BONNIE,AM PIT BULL TER / ENG BULLDOG,GREY / WHITE,07,Humber River-Black Creek,SEVERE,PARK - LEASH REQUIRED AREA,2022-10-20
# 175,M2L,ARCHIE,GERM SHEPHERD,BLACK / GOLD,15,Don Valley West,SEVERE,PUBLIC PROPERTY,2022-10-20
# 176,M9P,MAGNOLIA,ROTTWEILER / GERM SHEPHERD,BLACK / WHITE,01,Etobicoke North,SEVERE,OTHER PRIVATE PROPERTY,2022-10-23
# 177,M6B,HENNESSY,BOXER / MASTIFF,BROWN / WHITE,08,Eglinton-Lawrence,NON SEVERE,PUBLIC PROPERTY,2022-10-23
# 178,M1E,XENA,PRESA CANARIO,TAN / BLACK,24,Scarborough-Guildwood,SEVERE,PUBLIC PROPERTY,2022-10-25
# 179,M2J,RICK,GERM SHEPHERD,BLACK / BROWN,17,Don Valley North,NOT A BITE,OTHER PRIVATE PROPERTY,2022-10-25
# 180,M2N,BACON,GERM SHEPHERD,TAN / BLACK,18,Willowdale,SEVERE,PUBLIC PROPERTY,2022-10-31
# 181,M8W,TIBERIUS,ROTTWEILER,BLACK / TAN,03,Etobicoke-Lakeshore,SEVERE,PUBLIC PROPERTY,2022-11-06
# 182,M1T,KILO,FRENCH BULLDOG / ENG BULLDOG,GREY / WHITE,22,Scarborough-Agincourt,NON SEVERE,OTHER PRIVATE PROPERTY,2022-11-08
# 183,M3M,QUEENIE,AM PIT BULL TER / ENG BULLDOG,TAN,06,York Centre,NON SEVERE,PUBLIC PROPERTY,2022-12-04
# 184,M2J,DIESEL,GERM SHEPHERD,BLACK / TAN,17,Don Valley North,NON SEVERE,PARK - LEASH REQUIRED AREA,2022-12-06
# 185,M1W,JACK,CANE CORSO,BLACK / WHITE,22,Scarborough-Agincourt,SEVERE,PUBLIC PROPERTY,2022-12-11
# 186,M4L,SAM,LABRADOR RETR,FAWN,14,Toronto-Danforth,SEVERE,PUBLIC PROPERTY,2022-12-22
# 187,M6K,MABEL,HOUND / BEAGLE,WHITE / BLACK,10,Spadina-Fort York,SEVERE,PARK - LEASH REQUIRED AREA,2023-01-12
# 188,M1H,MOLLY,GERM SHEPHERD MIX,BLACK / TAN,24,Scarborough-Guildwood,SEVERE,PUBLIC PROPERTY,2023-02-20
# 189,M4K,BISHOP,GERM SH POINT,BROWN / WHITE,14,Toronto-Danforth,VERY SEVERE,PUBLIC PROPERTY,2023-02-21
# 190,M1M,PRINCE,AMER BULLDOG,WHITE / BROWN,20,Scarborough Southwest,SEVERE,OTHER PRIVATE PROPERTY,2023-03-09
# 191,M4P,CHARLES,GREAT PYRENEES / GOLDEN RETR,WHITE,12,Toronto-St. Paul's,NON SEVERE,PUBLIC PROPERTY,2023-03-31
# 192,M2K,GHOST,GERM SHEPHERD,BLACK,17,Don Valley North,SEVERE,PUBLIC PROPERTY,2023-04-08
# 193,M4C,CALLIE,BULLMASTIFF,BLACK / WHITE,19,Beaches-East York,NON SEVERE,PUBLIC PROPERTY,2023-04-13
# 194,M1J,MOOSE,CANE CORSO,TAN / GREY,21,Scarborough Centre,NOT A BITE,PUBLIC PROPERTY,2023-04-16
# 195,M3J,ROMMEL,GERM SHEPHERD,BROWN / BLACK,07,Humber River-Black Creek,SEVERE,OTHER PRIVATE PROPERTY,2023-04-23
# 196,M5M,HARLEY,AMER BULLDOG,BR BRINDLE,08,Eglinton-Lawrence,NON SEVERE,PUBLIC PROPERTY,2023-04-27
# 197,M6P,SHIKA,PATTERDALE TERR / AM PIT BULL TER,BLUE / GREY,04,Parkdale-High Park,SEVERE,PUBLIC PROPERTY,2023-04-28
# 198,M3L,BEAR,BORDER COLLIE / LABRADOR RETR,BLACK / WHITE,07,Humber River-Black Creek,NON SEVERE,OTHER PRIVATE PROPERTY,2023-05-01
# 199,M9A,TRIXIE,LABRADOR RETR / AM PIT BULL TER,BLACK / BR BRINDLE,02,Etobicoke Centre,SEVERE,OTHER PRIVATE PROPERTY,2023-05-02
# 200,M9A,TYSON,LABRADOR RETR / AM PIT BULL TER,BLACK,02,Etobicoke Centre,SEVERE,OTHER PRIVATE PROPERTY,2023-05-02
# 201,M5T,ZEPPELIN,GERM SHEPHERD,BLACK / TAN,11,University-Rosedale,NON SEVERE,OTHER PRIVATE PROPERTY,2023-05-09
# 202,M4L,DAISY,GERM SHEPHERD / LABRADOR RETR,BLACK / TAN,19,Beaches-East York,SEVERE,PARK - LEASH REQUIRED AREA,2023-05-11
# 203,M4J,LADY,GOLDEN RETR / POODLE STND,WHITE,14,Toronto-Danforth,SEVERE,PUBLIC PROPERTY,2023-05-14
# 204,M1W,LUNA,FILA,BR BRINDLE / WHITE,22,Scarborough-Agincourt,NOT A BITE,PUBLIC PROPERTY,2023-06-06
# 205,M4J,FRIDA,AUST SHEPHERD,TRICOLOUR,14,Toronto-Danforth,NON SEVERE,PARK - LEASH REQUIRED AREA,2023-06-18
# 206,M6B,TYSON,POODLE STND / GOLDEN RETR,TAN,08,Eglinton-Lawrence,SEVERE,PUBLIC PROPERTY,2023-06-21
# 207,M4S,GIGI,AM PIT BULL TER / LABRADOR RETR,TRICOLOUR,12,Toronto-St. Paul's,SEVERE,PUBLIC PROPERTY,2023-06-23
# 208,M6H,VENTURE,GOLDEN RETR,GOLD,09,Davenport,SEVERE,PUBLIC PROPERTY,2023-06-25
# 209,M1R,HERCEG,MASTIFF,TAN / BLACK,21,Scarborough Centre,SEVERE,OTHER PRIVATE PROPERTY,2023-06-25
# 210,M1G,REIGN,BELG MALINOIS / DUTCH SHEPHERD,BROWN / TAN,24,Scarborough-Guildwood,SEVERE,PUBLIC PROPERTY,2023-06-28
# 211,M6G,MAX,BULLDOG MIX,BLACK / WHITE,12,Toronto-St. Paul's,SEVERE,PARK - LEASH REQUIRED AREA,2023-06-29
# 212,M3A,ODIN,PRESA CANARIO,BL BRINDLE,16,Don Valley East,VERY SEVERE,OTHER PRIVATE PROPERTY,2023-06-29
# 213,M3A,FREYJA,AMER BULLDOG MIX,FAWN,16,Don Valley East,VERY SEVERE,OTHER PRIVATE PROPERTY,2023-06-29
# 214,M1M,COLD AS ICE (ARTIC),LABRADOR RETR,BLACK / WHITE,20,Scarborough Southwest,SEVERE,PARK - LEASH REQUIRED AREA,2023-06-30
# 215,M9C,LUCIFER,ENG BULLDOG / AM PIT BULL TER,FAWN / WHITE,02,Etobicoke Centre,NOT A BITE,PARK - LEASH REQUIRED AREA,2023-07-03
# 216,M3A,ARCHIE,PRESA CANARIO,BR BRINDLE / WHITE,16,Don Valley East,SEVERE,OTHER PRIVATE PROPERTY,2023-07-04
# 217,M1N,ZORRO,GERM SHEPHERD,BLACK / BROWN,20,Scarborough Southwest,NON SEVERE,PUBLIC PROPERTY,2023-07-07
# 218,M1C,JADE,BOXER,TAN / WHITE,25,Scarborough-Rouge Park,NOT A BITE,PARK - LEASH REQUIRED AREA,2023-07-10
# 219,M2N,HICHU,BORDER COLLIE,BLACK / WHITE,18,Willowdale,NOT A BITE,OTHER PRIVATE PROPERTY,2023-07-18
# 220,M4K,DRACO,ROTTWEILER / GERM SHEPHERD,BLACK / BROWN,14,Toronto-Danforth,NON SEVERE,PUBLIC PROPERTY,2023-07-18
# 221,M5T,REMY,ROTTWEILER MIX,BLACK,11,University-Rosedale,NON SEVERE,PUBLIC PROPERTY,2023-07-18
# 222,M1L,ATHENA,MASTIFF / ROTTWEILER,BROWN / WHITE,20,Scarborough Southwest,NOT A BITE,PUBLIC PROPERTY,2023-07-25
# 223,M6S,TILDA,BULL TERRIER,BR BRINDLE / WHITE,04,Parkdale-High Park,SEVERE,PARK - LEASH REQUIRED AREA,2023-07-30
# 224,M1S,ZEUS,AMER BULLDOG / CHOW CHOW,BLACK,23,Scarborough North,SEVERE,PARK - LEASH REQUIRED AREA,2023-08-02
# 225,M1S,BLANCA,AMER BULLDOG / CHOW CHOW,WHITE / BROWN,23,Scarborough North,SEVERE,PARK - LEASH REQUIRED AREA,2023-08-02
# 226,M1S,COOKIE,AMER BULLDOG / CHOW CHOW,BR BRINDLE,23,Scarborough North,VERY SEVERE,PARK - LEASH REQUIRED AREA,2023-08-02
# 227,M1E,RAGZ,BERNESE MTN DOG / POODLE STND,BLACK / WHITE,25,Scarborough-Rouge Park,SEVERE,PUBLIC PROPERTY,2023-08-12
# 228,M3C,ARCHIE,AMER BULLDOG / MASTIFF,GREY,16,Don Valley East,VERY SEVERE,OTHER PRIVATE PROPERTY,2023-08-20
# 229,M6C,MONTY,POODLE STND / BELG MALINOIS,BLACK,09,Davenport,SEVERE,PUBLIC PROPERTY,2023-08-28
# 230,M1E,LEVI,GERM SHEPHERD / SIBERIAN HUSKY,BLACK / WHITE,24,Scarborough-Guildwood,NOT A BITE,PUBLIC PROPERTY,2023-09-01
# 231,M3H,NALA,LABRADOR RETR,BLACK,06,York Centre,SEVERE,PARK - LEASH REQUIRED AREA,2023-09-01
# 232,M1L,MOTTO,AMER BULLDOG MIX,GREY / WHITE,20,Scarborough Southwest,SEVERE,PUBLIC PROPERTY,2023-09-04
# 233,M1M,SIMBA,GOLDEN RETR,GOLD,20,Scarborough Southwest,SEVERE,PUBLIC PROPERTY,2023-09-10
# 234,M6G,MANDO,AUST SHEPHERD,BROWN / WHITE,12,Toronto-St. Paul's,SEVERE,OTHER PRIVATE PROPERTY,2023-09-10
# 235,N3C,NALA,AMER BULLDOG MIX,BR BRINDLE / WHITE,,No Ward Info,SEVERE,OTHER PRIVATE PROPERTY,2023-09-16
# 236,M6M,ICE,AMER BULLDOG / CHINESE SHARPEI,BROWN / WHITE,05,York South-Weston,NON SEVERE,OTHER PRIVATE PROPERTY,2023-09-16
# 237,M5P,DOJI,AUST CATTLE DOG / ROTTWEILER,RED / TAN,12,Toronto-St. Paul's,SEVERE,PUBLIC PROPERTY,2023-09-26
# 238,M9C,NAIROBI,AMER BULLDOG,WHITE / TAN,02,Etobicoke Centre,SEVERE,PUBLIC PROPERTY,2023-10-07
# 239,M1E,LUNA,GERM SHEPHERD / LABRADOR RETR,BLACK,24,Scarborough-Guildwood,SEVERE,OTHER PRIVATE PROPERTY,2023-10-09
# 240,M4S,GIGI,ALASKAN HUSKY,BLACK,12,Toronto-St. Paul's,NON SEVERE,PUBLIC PROPERTY,2023-10-12
# 241,M9B,MAX,GOLDEN RETR,GOLD,02,Etobicoke Centre,NON SEVERE,OTHER PRIVATE PROPERTY,2023-10-13
# 242,M5R,TITAN,AMER BULLDOG / AMERICAN STAFF,GREY / WHITE,11,University-Rosedale,NON SEVERE,OTHER PRIVATE PROPERTY,2023-10-20
# 243,M6M,LEO,PARSON RUSS TER / SHIH TZU,TAN,05,York South-Weston,NOT A BITE,PUBLIC PROPERTY,2023-10-29
# 244,M4C,WHEELER,LABRADOR RETR / BOXER,BLACK / WHITE,19,Beaches-East York,SEVERE,PUBLIC PROPERTY,2023-11-05
# 245,M1K,EXO/AXEL,ROTTWEILER / LABRADOR RETR,BLACK / BROWN,20,Scarborough Southwest,NON SEVERE,PUBLIC PROPERTY,2023-11-15
# 246,M9R,LYRYX,GERM SHEPHERD,BLACK,01,Etobicoke North,SEVERE,OWNERS PROPERTY,2023-11-24
# 247,M6A,PENNY,GERM SHEPHERD / COLLIE SMOOTH,BLACK / BROWN,08,Eglinton-Lawrence,SEVERE,PUBLIC PROPERTY,2023-11-26
# 248,M6J,GUNNAR,CANE CORSO MIX,FAWN,10,Spadina-Fort York,NON SEVERE,PARK - LEASH FREE AREA,2023-11-28
# 249,M9W,KYRO,BOXER / DOGO ARGENTINO,BR BRINDLE,01,Etobicoke North,NOT A BITE,OTHER PRIVATE PROPERTY,2023-12-07
# 250,M6E,PRINCE,LABRADOR RETR / RHOD RIDGEBACK,APRICOT / BLACK,09,Davenport,SEVERE,PARK - LEASH FREE AREA,2017-02-21
# 251,M8Y,BRADY,ROTTWEILER,BLACK / BROWN,03,Etobicoke-Lakeshore,NOT A BITE,OTHER PRIVATE PROPERTY,2023-12-17
# 252,M4L,OBI WAN,ROTTWEILER,BLACK / BROWN,14,Toronto-Danforth,NON SEVERE,PUBLIC PROPERTY,2023-12-31
# 253,M2H,BENNY,AMER BULLDOG / STAFFORDSHIRE,BR BRINDLE,17,Don Valley North,SEVERE,OWNERS PROPERTY,2023-12-31
# 254,M6G,LUCA,GOLDEN RETR / AM PIT BULL TER,GREY / WHITE,11,University-Rosedale,SEVERE,PUBLIC PROPERTY,2024-01-20
# 255,M6J,PHOENIX,ROTTWEILER,BLACK / TAN,09,Davenport,NON SEVERE,PUBLIC PROPERTY,2024-01-27
# 256,M5A,CALVIN,BORDER COLLIE,BROWN / WHITE,10,Spadina-Fort York,NON SEVERE,PUBLIC PROPERTY,2024-01-28
# 257,M4A,KOBE,BOXER / STAFFORDSHIRE,GOLD / WHITE,16,Don Valley East,SEVERE,OTHER PRIVATE PROPERTY,2024-02-03
# 258,M4A,LUCKY,LABRADOR RETR / STAFFORDSHIRE,BLACK / WHITE,16,Don Valley East,NON SEVERE,OTHER PRIVATE PROPERTY,2024-02-03
# 259,M1W,LUNA,AM PIT BULL TER / ENG BULLDOG,BLACK / TRICOLOUR,22,Scarborough-Agincourt,NOT A BITE,OTHER PRIVATE PROPERTY,2024-02-05
# 260,M4S,BELLA,GERM SHEPHERD MIX,BROWN,12,Toronto-St. Paul's,NOT A BITE,PARK - LEASH REQUIRED AREA,2024-02-07
# 261,M5P,COOPER,BELG MALINOIS,BR BRINDLE,12,Toronto-St. Paul's,SEVERE,PARK - LEASH FREE AREA,2024-02-17
# 262,M4E,TITAN,AMER BULLDOG MIX,BEIGE / WHITE,19,Beaches-East York,SEVERE,OTHER PRIVATE PROPERTY,2024-02-20
# 263,M6J,CUBIK,SAMOYED,WHITE,10,Spadina-Fort York,NON SEVERE,PARK - LEASH REQUIRED AREA,2024-03-03
# 264,M4L,ROCKY,AMER BULLDOG / BOXER,BR BRINDLE,14,Toronto-Danforth,SEVERE,PUBLIC PROPERTY,2024-03-15
# 265,M9A,MOLLY,AMER BULLDOG,BLACK / GREY,02,Etobicoke Centre,SEVERE,PUBLIC PROPERTY,2024-03-24
# 266,M9P,CHUKIS/COOKIE,BERNESE MTN DOG / AMER BULLDOG,BROWN,01,Etobicoke North,NON SEVERE,OTHER PRIVATE PROPERTY,2024-03-28
# 267,M4L,NIKKI,GERM SHEPHERD,BLACK / TAN,19,Beaches-East York,SEVERE,OWNERS PROPERTY,2024-04-13
# 268,M9C,NELO,LABRADOR RETR / AMER BULLDOG,TAN,02,Etobicoke Centre,SEVERE,PUBLIC PROPERTY,2024-04-30
# 269,M6K,BULLET,STAFFORDSHIRE MIX,TAN / WHITE,04,Parkdale-High Park,SEVERE,OTHER PRIVATE PROPERTY,2024-05-01
# 270,M9C,MAGGIE,GERM SHEPHERD,BLACK / TAN,02,Etobicoke Centre,VERY SEVERE,PUBLIC PROPERTY,2024-05-04
# 271,M6B,SHADOW,AMER BULLDOG,GREY,08,Eglinton-Lawrence,SEVERE,PARK - LEASH REQUIRED AREA,2024-05-04
# 272,M9P,ASTON,DOBERMAN PINSCH,BLACK / TAN,02,Etobicoke Centre,SEVERE,PUBLIC PROPERTY,2024-05-06
# 273,M1B,WICK,AMER BULLDOG / ENG BULLDOG,BLUE,23,Scarborough North,NON SEVERE,PARK - LEASH REQUIRED AREA,2024-05-16
# 274,M1C,MULATTO,AMER BULLDOG,WHITE / BROWN,25,Scarborough-Rouge Park,SEVERE,PUBLIC PROPERTY,2024-05-21
# 275,M1C,DIAMOND,MASTIFF MIX,BLACK / WHITE,25,Scarborough-Rouge Park,SEVERE,PUBLIC PROPERTY,2024-05-21
# 276,M6B,ACE,AMER BULLDOG MIX,BLACK / WHITE,08,Eglinton-Lawrence,SEVERE,PUBLIC PROPERTY,2024-05-27
# 277,M6K,ONYX,AMER BULLDOG,BLACK / WHITE,10,Spadina-Fort York,NON SEVERE,PARK - LEASH FREE AREA,2024-06-01
# 278,M6G,HENNY,AMER BULLDOG,FAWN,11,University-Rosedale,SEVERE,PUBLIC PROPERTY,2024-06-02
# 279,M4N,PENNY,BERNESE MTN DOG / POODLE STND,BLACK / WHITE,15,Don Valley West,NON SEVERE,PUBLIC PROPERTY,2024-06-06
# 280,M1N,ZEUS,AMER BULLDOG,WHITE / TAN,20,Scarborough Southwest,NON SEVERE,PARK - LEASH REQUIRED AREA,2024-06-12
# 281,M6J,ZELOS,AMER BULLDOG,BLACK / WHITE,09,Davenport,SEVERE,OTHER PRIVATE PROPERTY,2024-06-24
# 282,M9W,ARROW,RHOD RIDGEBACK / AMER BULLDOG,BROWN / WHITE,01,Etobicoke North,SEVERE,PUBLIC PROPERTY,2024-07-01
# 283,M5M,RYDER LACEY,SIBERIAN HUSKY / AKITA,WHITE,08,Eglinton-Lawrence,SEVERE,OWNERS PROPERTY,2024-07-05
# 284,M1G,ROXY,ROTTWEILER / LABRADOR RETR,BLACK / TAN,24,Scarborough-Guildwood,SEVERE,OWNERS PROPERTY,2024-07-06
# 285,M9R,IRIS,GERM SHEPHERD,BLACK / TAN,02,Etobicoke Centre,NON SEVERE,PUBLIC PROPERTY,2024-07-06
# 286,M1E,SCOTIA,AMER BULLDOG / ENG BULLDOG,GREY,25,Scarborough-Rouge Park,NON SEVERE,OTHER PRIVATE PROPERTY,2024-07-07
# 287,M1M,FLY,GERM SHEPHERD,BROWN / BLACK,20,Scarborough Southwest,NON SEVERE,OTHER PRIVATE PROPERTY,2024-07-15
# 288,M8X,EGON,BULL TERRIER,WHITE,03,Etobicoke-Lakeshore,NON SEVERE,PUBLIC PROPERTY,2024-07-22
# 289,M1V,SKY,MALTESE,WHITE,22,Scarborough-Agincourt,NON SEVERE,PUBLIC PROPERTY,2024-07-25
# 290,M5R,OTTO,GERM SHEPHERD / AUST SHEPHERD,TRICOLOUR,11,University-Rosedale,NON SEVERE,OWNERS PROPERTY,2024-07-26
# 291,M9P,ROCCO,AM PIT BULL TER / ENG BULLDOG,TAN / WHITE,02,Etobicoke Centre,NON SEVERE,PUBLIC PROPERTY,2023-12-11
# 292,M1E,DEXTER,GREAT DANE / PRESA CANARIO,BR BRINDLE / WHITE,25,Scarborough-Rouge Park,SEVERE,PUBLIC PROPERTY,2024-08-11
# 293,M2J,KALI,IRISH WOLFHOUND,BLACK / GREY,17,Don Valley North,SEVERE,PUBLIC PROPERTY,2024-08-12
# 294,M5A,MICKEY,LABRADOR RETR / STAFFORDSHIRE,TAN / WHITE,13,Toronto Centre,SEVERE,PUBLIC PROPERTY,2024-08-26
# 295,M5V,FISH,AKITA,BROWN / WHITE,10,Spadina-Fort York,VERY SEVERE,PUBLIC PROPERTY,2024-08-29
# 296,M3L,NOVA,AM PIT BULL TER / ENG BULLDOG,TAN / TRICOLOUR,07,Humber River-Black Creek,NON SEVERE,PUBLIC PROPERTY,2024-09-01
# 297,M1C,KHLOE,ROTTWEILER MIX,BLACK / TAN,25,Scarborough-Rouge Park,SEVERE,OTHER PRIVATE PROPERTY,2024-09-01
# 298,M1C,MAGNUM,AMER BULLDOG MIX,WHITE / ORANGE,25,Scarborough-Rouge Park,SEVERE,OTHER PRIVATE PROPERTY,2024-09-01
# 299,M2H,TATIANA,GERM SHEPHERD,BLACK,17,Don Valley North,NON SEVERE,PUBLIC PROPERTY,2024-09-14
# 300,M2H,LUNA,GERM SHEPHERD,BLACK,17,Don Valley North,NON SEVERE,PUBLIC PROPERTY,2024-09-14
# 301,M2H,HERCULES,GERM SHEPHERD,BLACK,17,Don Valley North,NON SEVERE,PUBLIC PROPERTY,2024-09-14
# 302,M3C,HARPER,GERM SHEPHERD,BLACK,16,Don Valley East,NON SEVERE,OTHER PRIVATE PROPERTY,2024-09-16
# 303,M5P,DUKE,BERNESE MTN DOG / POODLE STND,TRICOLOUR,12,Toronto-St. Paul's,NON SEVERE,PUBLIC PROPERTY,2024-09-18
# 304,M2J,REMINGTON,GERM SHEPHERD,BLACK / ORANGE,17,Don Valley North,SEVERE,PUBLIC PROPERTY,2024-09-19
# 305,M6H,STEVE,GREAT DANE / AMER BULLDOG,BLACK / WHITE,09,Davenport,VERY SEVERE,OWNERS PROPERTY,2024-09-21
# 306,M2K,HACHI,AKITA,BEIGE,17,Don Valley North,SEVERE,PUBLIC PROPERTY,2024-09-27
# 307,M8W,CHOO,GERM SHEPHERD,TAN / BLACK,03,Etobicoke-Lakeshore,NOT A BITE,OTHER PRIVATE PROPERTY,2024-10-01
# 308,M9M,ROSIE,BORDER COLLIE / GERM SHEPHERD,BLACK / WHITE,07,Humber River-Black Creek,VERY SEVERE,PUBLIC PROPERTY,2024-10-23
# 309,M1X,KENZO,AMER BULLDOG,BROWN,25,Scarborough-Rouge Park,SEVERE,OWNERS PROPERTY,2024-10-25
# 310,M1G,MAARAM,GOLDEN RETR / POODLE STND,CREAM,24,Scarborough-Guildwood,SEVERE,PUBLIC PROPERTY,2024-10-25
# 311,M2N,SPENCER,AMER BULLDOG,BLACK / WHITE,18,Willowdale,SEVERE,OTHER PRIVATE PROPERTY,2024-11-05
# 312,M4C,GUCCI,MASTIFF,GREY / WHITE,19,Beaches-East York,NON SEVERE,OTHER PRIVATE PROPERTY,2024-11-08
# 313,M3B,MACY,LABRADOR RETR,GOLD,15,Don Valley West,NON SEVERE,PUBLIC PROPERTY,2024-11-24
# 314,M5T,JAZZ,AMER BULLDOG / STAFFORDSHIRE,RED,11,University-Rosedale,NON SEVERE,OWNERS PROPERTY,2024-12-11
# 315,M4J,CHAI,AM PIT BULL TER MIX,BROWN,14,Toronto-Danforth,SEVERE,PUBLIC PROPERTY,2024-12-24
# 316,M6G,PINKY,LABRADOR RETR MIX,BLACK / WHITE,11,University-Rosedale,SEVERE,PUBLIC PROPERTY,2024-12-27
# 317,M6G,BRUNO,ENG BULLDOG / PUG,TAN / WHITE,11,University-Rosedale,NON SEVERE,PUBLIC PROPERTY,2025-01-04
# 318,M4B,TARA,LABRADOR RETR / BORDER COLLIE,BLACK / WHITE,19,Beaches-East York,NON SEVERE,OWNERS PROPERTY,2025-01-12
# 319,M2H,OCEAN,PRESA CANARIO / MASTIFF,GOLD,17,Don Valley North,NON SEVERE,OTHER PRIVATE PROPERTY,2025-01-16
# 320,M4L,MABEL,BEAGLE / PUG,GOLD,19,Beaches-East York,NON SEVERE,OTHER PRIVATE PROPERTY,2025-01-17
# 321,M1M,PRINCE,POODLE STND MIX,GREY,20,Scarborough Southwest,SEVERE,OTHER PRIVATE PROPERTY,2025-01-17
# 322,M4E,AXL,ROTTWEILER,BLACK / BROWN,19,Beaches-East York,SEVERE,PUBLIC PROPERTY,2025-01-21
# 323,M4N,KOKO,JINDO MIX,BLACK,08,Eglinton-Lawrence,SEVERE,PARK - LEASH REQUIRED AREA,2025-01-23
# 324,M4W,SIMBA,GOLDEN RETR MIX,GOLD,11,University-Rosedale,SEVERE,PUBLIC PROPERTY,2025-02-08
# 325,M4S,PABLO,LABRADOR RETR,CHOCOLATE,12,Toronto-St. Paul's,SEVERE,OTHER PRIVATE PROPERTY,2025-02-14
# 326,M9W,KING,ROTTWEILER,BLACK / TAN,01,Etobicoke North,SEVERE,PUBLIC PROPERTY,2025-03-07
# 327,M3L,KOBE,GERM SHEPHERD,RED / WHITE,07,Humber River-Black Creek,SEVERE,OTHER PRIVATE PROPERTY,2025-03-13
# 328,M1M,ROCKY,ROTTWEILER,BLACK / TAN,20,Scarborough Southwest,SEVERE,PARK - LEASH FREE AREA,2025-03-17
# 329,M1T,LUNA,DOGO ARGENTINO / CANE CORSO,WHITE / BLACK,22,Scarborough-Agincourt,VERY SEVERE,OTHER PRIVATE PROPERTY,2025-03-19
# 330,M1P,BLAKE,LABRADOR RETR,BLACK,21,Scarborough Centre,SEVERE,PUBLIC PROPERTY,2025-04-23
# 331,M6E,KILO,AMER BULLDOG MIX,BLACK / WHITE,09,Davenport,VERY SEVERE,PUBLIC PROPERTY,2025-04-26
# 332,M1N,ZACH,BULLMASTIFF / AMER BULLDOG,TAN,20,Scarborough Southwest,SEVERE,PUBLIC PROPERTY,2024-08-06
#
# {'include_total': True, 'limit': 100, 'records_format': 'objects', 'resource_id': '61c41282-018c-4970-a801-1e83ee6796cb', 'total_estimation_threshold': None, 'records': [{'_id': 1, 'Forward_Sortation_Area': 'M6R', 'Name_of_Dog': 'CHLOE', 'Breed': 'BEAGLE MIX', 'Color': 'TAN / WHITE', 'Ward_Number': '04', 'Ward_Name': 'Parkdale-High Park', 'Bite_Circumstance': 'VERY SEVERE', 'Location_of_Incident': 'PUBLIC PROPERTY', 'Date_of_Dangerous_Act': '2017-03-09'}, {'_id': 2, 'Forward_Sortation_Area': 'M3M', 'Name_of_Dog': 'OSO', 'Breed': 'AKITA', 'Color': 'WHITE / BLACK', 'Ward_Number': '06', 'Ward_Name': 'York Centre', 'Bite_Circumstance': 'SEVERE', 'Location_of_Incident': 'PARK - LEASH REQUIRED AREA', 'Date_of_Dangerous_Act': '2017-03-11'}, {'_id': 3, 'Forward_Sortation_Area': 'M4N', 'Name_of_Dog': 'HOBBES', 'Breed': 'CANE CORSO / LABRADOR RETR', 'Color': 'BR BRINDLE', 'Ward_Number': '15', 'Ward_Name': 'Don Valley West', 'Bite_Circumstance': 'SEVERE', 'Location_of_Incident': 'OWNERS PROPERTY', 'Date_of_Dangerous_Act': '2017-03-18'}, {'_id': 4, 'Forward_Sortation_Area': 'M9W', 'Name_of_Dog': 'HUNTER', 'Breed': 'GOLDEN RETR', 'Color': 'GOLD', 'Ward_Number': '01', 'Ward_Name': 'Etobicoke North', 'Bite_Circumstance': 'SEVERE', 'Location_of_Incident': 'OTHER PRIVATE PROPERTY', 'Date_of_Dangerous_Act': '2017-03-23'}, {'_id': 5, 'Forward_Sortation_Area': 'M1E', 'Name_of_Dog': 'LILA', 'Breed': 'GERM SHEPHERD / AUST SHEPHERD', 'Color': 'BLACK / TAN', 'Ward_Number': '25', 'Ward_Name': 'Scarborough-Rouge Park', 'Bite_Circumstance': 'NON SEVERE', 'Location_of_Incident': 'PARK - LEASH FREE AREA', 'Date_of_Dangerous_Act': '2017-03-29'}, {'_id': 6, 'Forward_Sortation_Area': 'M3H', 'Name_of_Dog': 'BRODY', 'Breed': 'ALASKAN HUSKY MIX', 'Color': 'GREY / WHITE', 'Ward_Number': '06', 'Ward_Name': 'York Centre', 'Bite_Circumstance': 'NON SEVERE', 'Location_of_Incident': 'PARK - LEASH FREE AREA', 'Date_of_Dangerous_Act': '2017-04-16'}, {'_id': 7, 'Forward_Sortation_Area': 'M6R', 'Name_of_Dog': 'TANGO', 'Breed': 'AUST SHEPHERD', 'Color': 'RED MERLE', 'Ward_Number': '04', 'Ward_Name': 'Parkdale-High Park', 'Bite_Circumstance': 'NON SEVERE', 'Location_of_Incident': 'PUBLIC PROPERTY', 'Date_of_Dangerous_Act': '2017-04-19'}, {'_id': 8, 'Forward_Sortation_Area': 'M1B', 'Name_of_Dog': 'LEO', 'Breed': 'ROTTWEILER / BORDER COLLIE', 'Color': 'BLACK / BROWN', 'Ward_Number': '23', 'Ward_Name': 'Scarborough North', 'Bite_Circumstance': 'NON SEVERE', 'Location_of_Incident': 'PARK - LEASH REQUIRED AREA', 'Date_of_Dangerous_Act': '2017-04-26'}, {'_id': 9, 'Forward_Sortation_Area': 'M2R', 'Name_of_Dog': 'DASUL', 'Breed': 'JINDO', 'Color': 'WHITE', 'Ward_Number': '18', 'Ward_Name': 'Willowdale', 'Bite_Circumstance': 'NON SEVERE', 'Location_of_Incident': 'OTHER PRIVATE PROPERTY', 'Date_of_Dangerous_Act': '2017-06-21'}, {'_id': 10, 'Forward_Sortation_Area': 'M4B', 'Name_of_Dog': 'BRANDY', 'Breed': 'AM PIT BULL TER', 'Color': 'WHITE / TAN', 'Ward_Number': '19', 'Ward_Name': 'Beaches-East York', 'Bite_Circumstance': 'SEVERE', 'Location_of_Incident': 'OTHER PRIVATE PROPERTY', 'Date_of_Dangerous_Act': '2017-06-24'}, {'_id': 11, 'Forward_Sortation_Area': 'M1W', 'Name_of_Dog': 'TIGER', 'Breed': 'BOXER / AMER BULLDOG', 'Color': 'BROWN / WHITE', 'Ward_Number': '22', 'Ward_Name': 'Scarborough-Agincourt', 'Bite_Circumstance': 'SEVERE', 'Location_of_Incident': 'PARK - LEASH REQUIRED AREA', 'Date_of_Dangerous_Act': '2017-06-25'}, {'_id': 12, 'Forward_Sortation_Area': 'M4K', 'Name_of_Dog': 'NEMO', 'Breed': 'SIBERIAN HUSKY', 'Color': 'WHITE / GREY', 'Ward_Number': '14', 'Ward_Name': 'Toronto-Danforth', 'Bite_Circumstance': 'SEVERE', 'Location_of_Incident': 'PUBLIC PROPERTY', 'Date_of_Dangerous_Act': '2017-08-02'}, {'_id': 13, 'Forward_Sortation_Area': 'M9A', 'Name_of_Dog': 'ROCKY', 'Breed': 'GERM SHEPHERD MIX', 'Color': 'BLACK / TAN', 'Ward_Number': '02', 'Ward_Name': 'Etobicoke Centre', 'Bite_Circumstance': 'NON SEVERE', 'Location_of_Incident': 'OWNERS PROPERTY', 'Date_of_Dangerous_Act': ...
# {'help': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/help_show?name=resource_show', 'success': True, 'result': {'cache_last_updated': None, 'cache_url': None, 'created': '2024-04-12T20:18:34.546689', 'datastore_active': False, 'datastore_resource_id': '61c41282-018c-4970-a801-1e83ee6796cb', 'format': 'CSV', 'hash': '', 'id': '3bfc75b3-f4d9-42b4-8fbc-2fdd661fd67b', 'is_datastore_cache_file': True, 'last_modified': '2025-05-05T10:13:30.590578', 'metadata_modified': '2025-05-05T10:13:30.896257', 'mimetype': 'application/octet-stream', 'mimetype_inner': None, 'name': 'Dogs Issued Dangerous Dog Orders.csv', 'package_id': 'dogs-issued-dangerous-dog-orders', 'position': 1, 'resource_type': None, 'size': 34884, 'state': 'active', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/dogs-issued-dangerous-dog-orders/resource/3bfc75b3-f4d9-42b4-8fbc-2fdd661fd67b/download/dogs-issued-dangerous-dog-orders.csv', 'url_type': 'upload'}}
# {'help': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/help_show?name=resource_show', 'success': True, 'result': {'cache_last_updated': None, 'cache_url': None, 'created': '2024-04-12T20:18:35.525073', 'datastore_active': False, 'datastore_resource_id': '61c41282-018c-4970-a801-1e83ee6796cb', 'format': 'XML', 'hash': '', 'id': 'd633f2f6-050e-4429-8fe6-b63bf9dc80ae', 'is_datastore_cache_file': True, 'last_modified': '2025-05-05T10:13:31.412714', 'metadata_modified': '2025-05-05T10:13:31.499938', 'mimetype': 'application/octet-stream', 'mimetype_inner': None, 'name': 'Dogs Issued Dangerous Dog Orders.xml', 'package_id': 'dogs-issued-dangerous-dog-orders', 'position': 2, 'resource_type': None, 'size': 137619, 'state': 'active', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/dogs-issued-dangerous-dog-orders/resource/d633f2f6-050e-4429-8fe6-b63bf9dc80ae/download/dogs-issued-dangerous-dog-orders.xml', 'url_type': 'upload'}}
# {'help': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/help_show?name=resource_show', 'success': True, 'result': {'cache_last_updated': None, 'cache_url': None, 'created': '2024-04-12T20:18:36.469034', 'datastore_active': False, 'datastore_resource_id': '61c41282-018c-4970-a801-1e83ee6796cb', 'format': 'JSON', 'hash': '', 'id': '4f718b0f-e805-41f5-bb11-8148af5322c6', 'is_datastore_cache_file': True, 'last_modified': '2025-05-05T10:13:32.057793', 'metadata_modified': '2025-05-05T10:13:32.146049', 'mimetype': 'application/octet-stream', 'mimetype_inner': None, 'name': 'Dogs Issued Dangerous Dog Orders.json', 'package_id': 'dogs-issued-dangerous-dog-orders', 'position': 3, 'resource_type': None, 'size': 98499, 'state': 'active', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/dogs-issued-dangerous-dog-orders/resource/4f718b0f-e805-41f5-bb11-8148af5322c6/download/dogs-issued-dangerous-dog-orders.json', 'url_type': 'upload'}}

# %%
# Base URL for the API
base_url = "https://ckan0.cf.opendata.inter.prod-toronto.ca"

# API endpoint to retrieve package metadata
url = base_url + "/api/3/action/package_show"
params = {"id": "dogs-issued-dangerous-dog-orders"}
package = requests.get(url, params=params).json()

# Initialize an empty list to store data
data_list = []

# Loop through resources in the package
for idx, resource in enumerate(package["result"]["resources"]):
    # For datastore_active resources
    if resource["datastore_active"]:
        # API endpoint to retrieve data
        url = base_url + "/api/3/action/datastore_search"
        p = {"id": resource["id"]}
        resource_search_data = requests.get(url, params=p).json()["result"]["records"] #The records key contains the data
        # Append records to the data list
        data_list.extend(resource_search_data)

# Convert the data list to a Pandas DataFrame
df = pd.DataFrame(data_list)

# Display the DataFrame
print(df)
# Out:
#     _id Forward_Sortation_Area Name_of_Dog                          Breed  \
# 0     1                    M6R       CHLOE                     BEAGLE MIX
# 1     2                    M3M         OSO                          AKITA
# 2     3                    M4N      HOBBES     CANE CORSO / LABRADOR RETR
# 3     4                    M9W      HUNTER                    GOLDEN RETR
# 4     5                    M1E        LILA  GERM SHEPHERD / AUST SHEPHERD
# ..  ...                    ...         ...                            ...
# 95   96                    M4J        LULU                   AMER BULLDOG
# 96   97                    M6N      HABIBA                 DOGO ARGENTINO
# 97   98                    M6N       ZATAR                 DOGO ARGENTINO
# 98   99                    M3A      PEPPER                          BOXER
# 99  100                    M6A     GREYDEE                    COCKER SPAN
#
#                  Color Ward_Number               Ward_Name Bite_Circumstance  \
# 0          TAN / WHITE          04      Parkdale-High Park       VERY SEVERE
# 1        WHITE / BLACK          06             York Centre            SEVERE
# 2           BR BRINDLE          15         Don Valley West            SEVERE
# 3                 GOLD          01         Etobicoke North            SEVERE
# 4          BLACK / TAN          25  Scarborough-Rouge Park        NON SEVERE
# ..                 ...         ...                     ...               ...
# 95       BROWN / WHITE          14        Toronto-Danforth            SEVERE
# 96               WHITE          05       York South-Weston        NON SEVERE
# 97               WHITE          05       York South-Weston        NON SEVERE
# 98  BR BRINDLE / WHITE          16         Don Valley East        NOT A BITE
# 99           BLUE TICK          08       Eglinton-Lawrence        NOT A BITE
#
#           Location_of_Incident Date_of_Dangerous_Act
# 0              PUBLIC PROPERTY            2017-03-09
# 1   PARK - LEASH REQUIRED AREA            2017-03-11
# 2              OWNERS PROPERTY            2017-03-18
# 3       OTHER PRIVATE PROPERTY            2017-03-23
# 4       PARK - LEASH FREE AREA            2017-03-29
# ..                         ...                   ...
# 95             PUBLIC PROPERTY            2021-05-04
# 96      OTHER PRIVATE PROPERTY            2021-05-09
# 97      OTHER PRIVATE PROPERTY            2021-05-09
# 98             PUBLIC PROPERTY            2021-05-11
# 99      OTHER PRIVATE PROPERTY            2021-05-17
#
# [100 rows x 10 columns]

# %%
x1 =df['Breed']
print(x1)
y1 = df['Breed'].value_counts()
# Out:
# 0                        BEAGLE MIX
# 1                             AKITA
# 2        CANE CORSO / LABRADOR RETR
# 3                       GOLDEN RETR
# 4     GERM SHEPHERD / AUST SHEPHERD
#                   ...
# 95                     AMER BULLDOG
# 96                   DOGO ARGENTINO
# 97                   DOGO ARGENTINO
# 98                            BOXER
# 99                      COCKER SPAN
# Name: Breed, Length: 100, dtype: object

# %%
print(y1)
# Out:
# Breed
# GERM SHEPHERD                     10
# AMER BULLDOG                       6
# GERM SHEPHERD MIX                  4
# SIBERIAN HUSKY                     3
# AMER BULLDOG MIX                   3
#                                   ..
# SHIH TZU                           1
# SIBERIAN HUSKY / GERM SHEPHERD     1
# SC WHEAT TERR                      1
# MIN PINSCHER MIX                   1
# NS DUCK TOLLING                    1
# Name: count, Length: 64, dtype: int64

# %%
y1 = df['Breed'].value_counts()

top_10_breeds = y1.head(10) # Get the top 10 breeds
plt.figure(figsize=(10, 6))
plt.bar(top_10_breeds.index, top_10_breeds.values)
plt.xlabel('Breed')
plt.ylabel('Frequency')
plt.title('Top 10 Breeds')
plt.xticks(rotation=45,ha='right')  # Rotate x-axis labels for better readability
plt.show()

# %%
#Bite severity split graph
group_data = df.groupby(['Breed', 'Bite_Circumstance']).size().unstack(fill_value=0)
top_10_breeds = df['Breed'].value_counts().head(10).index
group_data = group_data.loc[top_10_breeds]

plt.figure(figsize=(12, 6))
group_data.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('Bite Severity by Breed (Top 10 Breeds)')
plt.xlabel('Breed')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Bite Severity')
plt.tight_layout()
plt.show()

# %%
from PIL import Image #to open images
import requests #to get images from URLs
from io import BytesIO #to store images
response = requests.get("https://www.k-9services.net/uploads/2/2/4/8/22483006/published/345669982-535743158767728-6625762902621306422-n.jpg?1736964158")
image_file = BytesIO(response.content)
image = Image.open(image_file)

# %%
#Bite severity split graph
group_data = df.groupby(['Breed', 'Bite_Circumstance']).size().unstack(fill_value=0)
top_10_breeds = df['Breed'].value_counts().head(10).index
group_data = group_data.loc[top_10_breeds]

fig = plt.figure(figsize=(12, 6))
group_data.plot(kind='bar', stacked=True, colormap='viridis')
plt.title('Bite Severity by Breed (Top 10 Breeds)')
plt.xlabel('Breed')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Bite Severity')
plt.tight_layout()

ax_image = fig.add_axes([0.1,0.11,0.5,0.35])
ax_image.imshow(image)
ax_image.axis('off') #This will remove the axis from the image
response = requests.get("https://pngimg.com/uploads/german_shepherd/german_shepherd_PNG13.png")
image_file = BytesIO(response.content)
image = Image.open(image_file)
ax_image.imshow(image)
plt.show()

# %%
#Final Code for Assignment 3

#importing libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
import PIL as pil
import requests
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
from PIL import Image
from io import BytesIO
import seaborn as sns
# Toronto Open Data is stored in a CKAN instance. It's APIs are documented here:
# https://docs.ckan.org/en/latest/api/

# Base URL for the API
base_url = "https://ckan0.cf.opendata.inter.prod-toronto.ca"

# API endpoint to retrieve package metadata
url = base_url + "/api/3/action/package_show"
params = {"id": "dogs-issued-dangerous-dog-orders"}
package = requests.get(url, params=params).json()

# Initialize an empty list to store data
data_list = []

# Loop through resources in the package
for idx, resource in enumerate(package["result"]["resources"]):
    # For datastore_active resources
    if resource["datastore_active"]:
        # API endpoint to retrieve data
        url = base_url + "/api/3/action/datastore_search"
        p = {"id": resource["id"]}
        resource_search_data = requests.get(url, params=p).json()["result"]["records"] #The records key contains the data
        # Append records to the data list
        data_list.extend(resource_search_data)

# Convert the data list to a Pandas DataFrame
df = pd.DataFrame(data_list)

# Display the DataFrame
print(df)



# Group the data by 'Breed' and 'Bite_Circumstance' and count occurrences
group_data = df.groupby(['Breed', 'Bite_Circumstance']).size().unstack(fill_value=0)

# Subset the top 10 breeds
top_10_breeds = df['Breed'].value_counts().head(10).index
group_data = group_data.reindex(top_10_breeds, fill_value=0)  # Reindex to avoid KeyError

# Plot the stacked bar chart
fig = plt.figure(figsize=(12, 8))  # Create a Figure object
ax = fig.add_subplot(111)  # Add a subplot to the Figure

group_data.plot(kind='bar', stacked=True, colormap='viridis', ax=ax)

# Add labels and title
ax.set_title('Bite Severity by Breed (Top 10 Breeds)')
ax.set_xlabel('Breed')
ax.set_ylabel('Frequency')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')  # Rotate x-axis labels
ax.legend(title='Bite Severity')
ax.yaxis.set_major_locator(MultipleLocator(1)) #Set y-axis frequency to 1 
ax.grid(True, axis='y',linestyle='--',alpha=0.5) 
plt.tight_layout()

# Add an image to the plot
ax_image = fig.add_axes([0.08, 0.7, 0.15, 0.25])  # Define position of the image axes
ax_image.axis('off')  # Turn off axes for the image

# Load and display an image
response = requests.get("https://pngimg.com/uploads/german_shepherd/german_shepherd_PNG13.png")
image_file = BytesIO(response.content)
image = Image.open(image_file)
ax_image.imshow(image)
# Out:
#     _id Forward_Sortation_Area Name_of_Dog                          Breed  \
# 0     1                    M6R       CHLOE                     BEAGLE MIX
# 1     2                    M3M         OSO                          AKITA
# 2     3                    M4N      HOBBES     CANE CORSO / LABRADOR RETR
# 3     4                    M9W      HUNTER                    GOLDEN RETR
# 4     5                    M1E        LILA  GERM SHEPHERD / AUST SHEPHERD
# ..  ...                    ...         ...                            ...
# 95   96                    M4J        LULU                   AMER BULLDOG
# 96   97                    M6N      HABIBA                 DOGO ARGENTINO
# 97   98                    M6N       ZATAR                 DOGO ARGENTINO
# 98   99                    M3A      PEPPER                          BOXER
# 99  100                    M6A     GREYDEE                    COCKER SPAN
#
#                  Color Ward_Number               Ward_Name Bite_Circumstance  \
# 0          TAN / WHITE          04      Parkdale-High Park       VERY SEVERE
# 1        WHITE / BLACK          06             York Centre            SEVERE
# 2           BR BRINDLE          15         Don Valley West            SEVERE
# 3                 GOLD          01         Etobicoke North            SEVERE
# 4          BLACK / TAN          25  Scarborough-Rouge Park        NON SEVERE
# ..                 ...         ...                     ...               ...
# 95       BROWN / WHITE          14        Toronto-Danforth            SEVERE
# 96               WHITE          05       York South-Weston        NON SEVERE
# 97               WHITE          05       York South-Weston        NON SEVERE
# 98  BR BRINDLE / WHITE          16         Don Valley East        NOT A BITE
# 99           BLUE TICK          08       Eglinton-Lawrence        NOT A BITE
#
#           Location_of_Incident Date_of_Dangerous_Act
# 0              PUBLIC PROPERTY            2017-03-09
# 1   PARK - LEASH REQUIRED AREA            2017-03-11
# 2              OWNERS PROPERTY            2017-03-18
# 3       OTHER PRIVATE PROPERTY            2017-03-23
# 4       PARK - LEASH FREE AREA            2017-03-29
# ..                         ...                   ...
# 95             PUBLIC PROPERTY            2021-05-04
# 96      OTHER PRIVATE PROPERTY            2021-05-09
# 97      OTHER PRIVATE PROPERTY            2021-05-09
# 98             PUBLIC PROPERTY            2021-05-11
# 99      OTHER PRIVATE PROPERTY            2021-05-17
#
# [100 rows x 10 columns]
