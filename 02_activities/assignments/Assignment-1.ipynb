# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
np.random.seed(613)
x = np.arange(50)
y = np.random.randint(0,100,50)

fig, ax = plt.subplots(figsize=(5,3)) #defining the size of the graph
#ax.scatter(x,y)
#ax.bar(x,y)
ax.hist(y)# Displaying the data as histogram
# Out:
# (array([4., 6., 2., 5., 7., 6., 4., 3., 9., 4.]),
#  array([ 6. , 15.2, 24.4, 33.6, 42.8, 52. , 61.2, 70.4, 79.6, 88.8, 98. ]),
#  <BarContainer object of 10 artists>)

# %%
font1 = {'family':'sans-serif','color':'blue','size':20} #Stablishing color and size 1
font2 = {'family':'monospace','color':'green','size':14} #Stablishing color and size 2

fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y)

ax.set_title('Total growght over time', fontdict=font1,loc='left') #Assigning color, size, and position to the title
ax.set_ylabel('Total growth',fontdict=font2) #Assigning color and size to Y's
ax.set_xlabel('Years since start',fontdict=font2)# Assigning color and size to X's
# Out:
# Text(0.5, 0, 'Years since start')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax. scatter(x,
            y,
            #marker = '*',#Testing marker with different sign
            marker = '>',
            color = 'indigo')

# %%
fig, ax = plt.subplots(figsize=(5,3))
ax.plot(x,y,marker = '*',
        color = '#7425B9',
        linestyle = '--',
        linewidth = 2,
        markersize = 12,
        markeredgecolor = '#FA9359',
        markerfacecolor = '#000000')
ax.grid(axis='y',color = '#7425B9',linewidth = 2, linestyle = '--') # Assigning color, width and style of the line for the grid

# %%
# This is an exercise i copied from the website that was provided in class, to play around with code we saw in class
# library
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20,5)
# create random data
values=[12,11,31,30]
 
# Create a pieplot
plt.pie(values);
plt.show();
