# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import PIL
import requests
import scipy

np.random.seed(613)
x = np.arange(50)
y1 = np.random.randint(0,100,50)
y2 = np.random.randint(0,100,50)

# %%
fig, ax = plt.subplots(figsize=(8,2)) 
ax.plot(x,y1, label = "person 1")
ax.plot(x,y2, label = "person 2")
ax.legend(loc = 'lower right')
fig.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_13736\1177166702.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(8,2)) 
ax.plot(x,y1, label = "person 1")
ax.plot(x,y2, label = "person 2")
ax.legend(loc = 'upper left',bbox_to_anchor =(1,1))
fig.show()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_13736\2683771987.py:5: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
fig, ax = plt.subplots(figsize=(5,3)) 
ax.plot(x,y1, label = "person 1")
ax.plot(x,y2, label = "person 2")
ax.legend(loc = 'upper left',bbox_to_anchor =(1,1))
